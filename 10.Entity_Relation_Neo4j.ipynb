# %% [markdown]
# # Restaurant Entity-Relation Neo4j Knowledge Graph
#
# This notebook demonstrates the creation and querying of a knowledge graph for restaurant data using Neo4j. The knowledge graph captures various aspects of restaurants including their locations, ratings, amenities, and relationships.
#
# ## Overview
#
# The notebook implements a comprehensive restaurant recommendation system using Neo4j graph database. It processes restaurant data to create a rich knowledge graph that captures various relationships between restaurants and their attributes, enabling complex queries and recommendations.
#
# ### Key Components:
#
# 1. **Data Loading and Processing**
#    - Loads restaurant data from CSV files
#    - Implements data normalization and text processing utilities
#    - Handles Turkish character normalization
#
# 2. **Knowledge Graph Structure**
#    - **Nodes**: Restaurant, Aspect, Location, Amenity, Occasion, MenuItem
#    - **Relationships**:
#      - RATED_FOR: Restaurant ratings for different aspects
#      - SERVES: Menu items served by restaurants
#      - LOCATED_IN: Restaurant locations
#      - HAS_AMENITY: Restaurant amenities
#      - SUITS_OCCASION: Suitable occasions for restaurants
#
# 3. **Features**
#    - Sentiment analysis for restaurant aspects
#    - Menu item detection and classification
#    - Location-based querying
#    - Multi-criteria restaurant search
#    - Comprehensive rating system
#
# 4. **Query Capabilities**
#    - Location-based searches (city/district)
#    - Menu-based filtering
#    - Amenity-based filtering
#    - Occasion-based recommendations
#    - Rating-based sorting and filtering
#
# ### Technical Implementation:
#
# - **Data Processing**:
#   - JSON parsing and normalization
#   - Text normalization (Turkish-language aware)
#   - Aspect mapping and categorization
#   - Sentiment analysis using keyword sets
#
# - **Neo4j Integration**:
#   - Custom Neo4j knowledge graph class
#   - Efficient batch import processes
#   - Constraint and index management
#   - Complex relationship queries
#
# - **Search Interface**:
#   - Natural language query parsing
#   - Multi-criteria search support
#   - Formatted result presentation
#   - Interactive chatbot interface

# %% [markdown]
# ## Cell 1: Data Loading and Initial Setup

# %%
import pandas as pd
import json
import re
import datetime

data = pd.read_csv('/Users/Serra/Desktop/bitirme/kullanılan csvler/Son_Data_Score.csv')

# %%
data.head()
# Out:
#                         Mekan_Adı       Ilce        Il  Total_Weighted_Score  \
# 0               01_adana_durumluk  Etimesgut    Ankara              0.028966
# 1  01_adanali_ismail_ustanin_yeri    Çankaya    Ankara              0.160363
# 2               06_ankara_kokorec  Pursaklar    Ankara              0.000000
# 3               100_more_alsancak      Konak     İzmir              0.183239
# 4            10_numara_restaurant    Çatalca  İstanbul              0.135506
#
#    Tat_Score  Hizmet_Score  Ortam_Score  Fiyat-Performans_Score  \
# 0   0.755000      0.225000     0.850000                0.628571
# 1   0.748000      0.492188     0.718000                0.236667
# 2        NaN           NaN          NaN                     NaN
# 3   0.764706      0.730000     0.851724                0.296875
# 4   0.827778      0.821739     0.864000                0.559091
#
#    Menü Çeşitliliği_Score  Temizlik_Score  \
# 0                     NaN        1.000000
# 1                0.392105        0.470000
# 2                     NaN             NaN
# 3                0.700000        0.955556
# 4                0.960000        1.000000
#
#                                                 Özet  \
# 0  Restoran, özellikle Adana dürüm ve kebaplarıyl...
# 1  Bu restoran, özellikle **lezzetli Adana kebabı...
# 2  Bu restoran, özellikle kokoreç konusunda öne ç...
# 3  %100&MORE Alsancak, İzmir'in popüler mekanları...
# 4  Restoran, samimi ve sıcak bir ortamıyla öne çı...
#
#                                               Entity
# 0  {"restaurant": "01_adana_durumluk", "language"...
# 1  {"restaurant": "01_adanali_ismail_ustanin_yeri...
# 2  {"restaurant": "06_ankara_kokorec", "language"...
# 3  {\n  "restaurant": "100_more_alsancak",\n  "la...
# 4  {\n  "restaurant": "10_numara_restaurant",\n  ...

# %% [markdown]
# ## Utility Functions and Data Processing Helpers

# %%
# ========= 1) Yardımcılar =========
import re, json, ast, datetime
import pandas as pd
import unicodedata

def now_utc_iso():
    return datetime.datetime.now(datetime.timezone.utc).isoformat()

def norm(s: str) -> str:
    """Normalize plain strings, Türkçe karakter uyumlu"""
    if s is None:
        return ""
    s = str(s).strip()
    s = unicodedata.normalize("NFC", s)  # Unicode normalize
    # Türkçe özel case map
    tr_map = str.maketrans({"I": "ı", "İ": "i"})
    s = s.translate(tr_map).casefold()
    return s

def normalize_surface(s: str) -> str:
    """Normalize for surface names (menu, aspect), Türkçe karakter uyumlu"""
    s = (s or "").strip()
    s = unicodedata.normalize("NFC", s)
    tr_map = str.maketrans({"I": "ı", "İ": "i"})
    s = s.translate(tr_map).casefold()
    s = re.sub(r"[^\w\sçğıöşü-]+", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

def safe_parse_summary(raw):
    if raw is None or (isinstance(raw, float) and pd.isna(raw)):
        return None
    if isinstance(raw, dict):
        return raw
    if isinstance(raw, (bytes, bytearray)):
        raw = raw.decode("utf-8", "ignore")
    s = str(raw).strip()
    if not s:
        return None
    s = s.lstrip("\ufeff").replace("“","\"").replace("”","\"").replace("’","'").replace("‘","'")
    try:
        return json.loads(s)
    except:
        pass
    if "{" in s and "}" in s:
        core = s[s.find("{"): s.rfind("}")+1]
        try:
            return json.loads(core)
        except:
            core2 = re.sub(r",\s*([}\]])", r"\1", core)
            try:
                return json.loads(core2)
            except:
                pass
    try:
        obj = ast.literal_eval(s)
        if isinstance(obj, dict):
            return obj
    except:
        pass
    return None

# ========= 2) Sözlükler / Haritalar =========
ASPECT_MAP = {
  "Tat":"TASTE","Hizmet":"SERVICE","Ortam":"AMBIENCE",
  "Fiyat-Performans":"VALUE","Menü Çeşitliliği":"MENU_VARIETY","Temizlik":"CLEANLINESS"
}

NEG_HINTS = {"değil","yetersiz","küçük","pahalı","kirli","eksik","sorun", "sorunlu","sıkıntı"}
POS_HINTS = {"lezzetli","doyurucu","uygun fiyat","güler yüzlü","temiz"}

AMENITIES = {"otopark","çocuk parkı","bahçe","deniz manzarası","canlı müzik","alkolsüz","teras"}
OCCASIONS = {"romantik","aile","sakin","doğum günü","iş yemeği", "eğlenceli"}

# Menü isimleri (çekirdek; kendi KB’inle genişlet)
MENU_LEX = {
    "adana dürüm","kebap","lahmacun","pide","köfte","döner","balık","çorba","salata",
    "meze","tatlı","baklava","künefe","sushi","ramen","pizza","hamburger","burger",
    "biftek","mantı","falafel","humus","shawarma","taco","burrito","curry",
    "penne","spaghetti","risotto","gnocchi","türk mutfağı", "geleneksel türk mutfağı"
}
MENU_PAT = re.compile(
    r"\b(kebap|dürüm|döner|pide|lahmacun|köfte|mantı|balık|çorba|salata|meze|tatlı|"
    r"baklava|künefe|sushi|ramen|pizza|hamburger|burger|biftek|falafel|humus|shawarma|"
    r"taco|burrito|curry|penne|spaghetti|risotto|gnocchi)s?\b",
    flags=re.IGNORECASE
)

def sentiment_from(polarity, spans):
    text = " ".join(spans or []).lower()
    if any(w in text for w in NEG_HINTS): return "negative"
    if any(w in text for w in POS_HINTS): return "positive"
    if polarity == "+": return "positive"
    if polarity == "-": return "negative"
    return "neutral"

def is_menu_item(term: str) -> bool:
    t = normalize_surface(term)
    return (t in MENU_LEX) or bool(MENU_PAT.search(t))

REL_LOCAL_MAP = {
    "co-occur": "CO_OCCUR",
    "co_occur": "CO_OCCUR",
    "contrast": "CONTRASTS",
    "contrasts": "CONTRASTS",
    "boosts": "BOOSTS",
    "implies": "IMPLIES",
    "affects_negatively": "AFFECTS_NEGATIVELY"
}

# %% [markdown]
# ## Knowledge Graph Edge Builder
# Bu cell'de restaurant verilerinden knowledge graph edge'leri oluşturan ana fonksiyon tanımlanır:
# - RATED_FOR: Restaurant'ların aspect'lere göre değerlendirmeleri
# - SERVES: Restaurant'ların servis ettiği menü itemları
# - HAS_AMENITY: Restaurant'ların sahip olduğu imkanlar (otopark, bahçe, vb.)
# - SUITS_OCCASION: Restaurant'ların uygun olduğu durumlar (romantik, aile, vb.)
# - LOCATED_IN: Restaurant'ların konum bilgileri (il/ilçe)

# %%
def build_edges(doc, source="llm_entity_json", il=None, ilce=None):
    rest = f"restaurant:{norm(doc.get('restaurant'))}"
    edges = []
    entities = doc.get("entities") or {}

    for k, items in entities.items():
        group = ASPECT_MAP.get(k)
        if not group:
            continue
        for it in items:
            name = (it.get("normalize_to") or it.get("name") or "").strip()
            if not name:
                continue
            spans = it.get("evidence_spans", []) or []
            sent = sentiment_from(it.get("polarity"), spans)
            sal = float(it.get("salience", 0.5))
            conf = float(it.get("confidence", 0.5))
            score = round(0.5*sal + 0.5*conf, 3)

            if group == "TASTE":
                # Menü ise: SERVES yaz, RATED_FOR yazma
                if is_menu_item(name):
                    edges.append({
                        "head": rest, "relation": "SERVES",
                        "tail": f"menu:{normalize_surface(name)}",
                        "props": {
                            "confidence": min(1.0, conf + 0.1),
                            "evidence_spans": spans, "source": source, "updated_at": now_utc_iso()
                        }
                    })
                    continue
                # Menü değilse gerçek TASTE aspekti → RATED_FOR
                edges.append({
                    "head": rest, "relation": "RATED_FOR",
                    "tail": f"aspect:{normalize_surface(name)}",
                    "props": {
                        "dimension": "TASTE", "sentiment": sent, "score": score,
                        "confidence": conf, "evidence_spans": spans, "votes": 1,
                        "source": source, "updated_at": now_utc_iso()
                    }
                })
                continue

            # Diğer gruplar: RATED_FOR
            edges.append({
                "head": rest, "relation": "RATED_FOR",
                "tail": f"aspect:{normalize_surface(name)}",
                "props": {
                    "dimension": group, "sentiment": sent, "score": score,
                    "confidence": conf, "evidence_spans": spans, "votes": 1,
                    "source": source, "updated_at": now_utc_iso()
                }
            })

    # Amenity & Occasion (span araması)
    all_text = " ".join([
        " ".join(e.get("evidence_spans", []) or [])
        for arr in entities.values() for e in arr
    ]).lower()

    for amen in AMENITIES:
        if amen in all_text:
            edges.append({
                "head": rest, "relation": "HAS_AMENITY",
                "tail": f"amenity:{amen}",
                "props": {
                    "availability": "true", "confidence": 0.8,
                    "evidence_spans": [amen], "source": source, "updated_at": now_utc_iso()
                }
            })

    for occ in OCCASIONS:
        if occ in all_text:
            edges.append({
                "head": rest, "relation": "SUITS_OCCASION",
                "tail": f"occasion:{occ}",
                "props": {
                    "strength": "medium", "confidence": 0.75,
                    "evidence_spans": [occ], "source": source, "updated_at": now_utc_iso()
                }
            })

    # LOCATED_IN: İl / İlçe kolonlarından
    if ilce and str(ilce).strip():
        district_name = norm(str(ilce))
        edges.append({
            "head": rest, "relation": "LOCATED_IN",
            "tail": f"location:{district_name}",
            "props": {
                "level": "district",
                "name": district_name,   # 🔹 name eklendi
                "confidence": 1.0,
                "evidence_spans": [],
                "source": source,
                "updated_at": now_utc_iso()
            }
        })
    if il and str(il).strip():
        city_name = norm(str(il))
        edges.append({
            "head": rest, "relation": "LOCATED_IN",
            "tail": f"location:{city_name}",
            "props": {
                "level": "city",
                "name": city_name,       # 🔹 name eklendi
                "confidence": 1.0,
                "evidence_spans": [],
                "source": source,
                "updated_at": now_utc_iso()
            }
        })

            # 3.5 NEW: relations_local → edges
    for lr in (doc.get("relations_local") or []):
        rtype = REL_LOCAL_MAP.get(str(lr.get("type", "")).lower())
        if not rtype:
            continue
        a = lr.get("a"); b = lr.get("b")
        if not a or not b:
            continue
        edges.append({
            "head": f"aspect:{normalize_surface(a)}",
            "relation": rtype,
            "tail": f"aspect:{normalize_surface(b)}",
            "props": {
                "strength": lr.get("strength"),
                "source": source, "updated_at": now_utc_iso()
            }
        })

    return edges

# %% [markdown]
# ## Edge Generation and DataFrame Creation
# Bu cell'de tüm DataFrame satırları üzerinde döngü yapılarak edge'ler oluşturulur:
# - Her satırdaki JSON verisi parse edilir
# - build_edges fonksiyonu çağırılarak ilişkiler çıkarılır
# - Tüm edge'ler tek bir DataFrame'de toplanır
# - LOCATED_IN edge'lerinin sayısı kontrol edilir (498 adet)

# %%
# ========= 4) DataFrame üzerinde çalıştır =========
city_col     = "Il"    # İl için kolon adı
district_col = "Ilce"  # İlçe için kolon adı

all_edges = []
for idx, row in data.iterrows():
    try:
        doc = safe_parse_summary(row.get("Entity"))
        if doc is None:
            continue

        il   = row.get(city_col)      # "Sehir"
        ilce = row.get(district_col)  # "Ilce"

        edges = build_edges(doc, source=f"row_{idx}", il=il, ilce=ilce)
        for e in edges:
            e["doc_index"] = idx
            all_edges.append(e)
    except Exception as ex:
        print(f"[ERROR] row {idx}: {ex}")

edges_df = pd.DataFrame(all_edges)

# Hızlı kontrol:
print("LOCATED_IN edge sayısı:", (edges_df["relation"] == "LOCATED_IN").sum())
print(edges_df[edges_df["relation"] == "LOCATED_IN"].head(20))
# Out:
# LOCATED_IN edge sayısı: 4670
#                                                   head    relation  \
# 12                        restaurant:01_adana_durumluk  LOCATED_IN
# 13                        restaurant:01_adana_durumluk  LOCATED_IN
# 32           restaurant:01_adanali_ismail_ustanin_yeri  LOCATED_IN
# 33           restaurant:01_adanali_ismail_ustanin_yeri  LOCATED_IN
# 48                        restaurant:06_ankara_kokorec  LOCATED_IN
# 49                        restaurant:06_ankara_kokorec  LOCATED_IN
# 69                        restaurant:100_more_alsancak  LOCATED_IN
# 70                        restaurant:100_more_alsancak  LOCATED_IN
# 86                     restaurant:10_numara_restaurant  LOCATED_IN
# 87                     restaurant:10_numara_restaurant  LOCATED_IN
# 115                   restaurant:1453_osmanli_bostanli  LOCATED_IN
# 116                   restaurant:1453_osmanli_bostanli  LOCATED_IN
# 141  restaurant:16_roof_swissotel_the_bosphorus_ist...  LOCATED_IN
# 142  restaurant:16_roof_swissotel_the_bosphorus_ist...  LOCATED_IN
# 165      restaurant:1983beyoglu_cikolatakahve_kecioren  LOCATED_IN
# 166      restaurant:1983beyoglu_cikolatakahve_kecioren  LOCATED_IN
# 190            restaurant:1999_atasehir_esinin_mutfagi  LOCATED_IN
# 191            restaurant:1999_atasehir_esinin_mutfagi  LOCATED_IN
# 204              restaurant:19_pide_kebap_ustanin_yeri  LOCATED_IN
# 205              restaurant:19_pide_kebap_ustanin_yeri  LOCATED_IN
#
#                        tail  \
# 12       location:etimesgut
# 13          location:ankara
# 32         location:çankaya
# 33          location:ankara
# 48       location:pursaklar
# 49          location:ankara
# 69           location:konak
# 70           location:izmir
# 86         location:çatalca
# 87        location:istanbul
# 115      location:karşıyaka
# 116          location:izmir
# 141       location:beşiktaş
# 142       location:istanbul
# 165       location:keçiören
# 166         location:ankara
# 190       location:ataşehir
# 191       location:istanbul
# 204  location:kahramankazan
# 205         location:ankara
#
#                                                  props  doc_index
# 12   {'level': 'district', 'name': 'etimesgut', 'co...          0
# 13   {'level': 'city', 'name': 'ankara', 'confidenc...          0
# 32   {'level': 'district', 'name': 'çankaya', 'conf...          1
# 33   {'level': 'city', 'name': 'ankara', 'confidenc...          1
# 48   {'level': 'district', 'name': 'pursaklar', 'co...          2
# 49   {'level': 'city', 'name': 'ankara', 'confidenc...          2
# 69   {'level': 'district', 'name': 'konak', 'confid...          3
# 70   {'level': 'city', 'name': 'izmir', 'confidence...          3
# 86   {'level': 'district', 'name': 'çatalca', 'conf...          4
# 87   {'level': 'city', 'name': 'istanbul', 'confide...          4
# 115  {'level': 'district', 'name': 'karşıyaka', 'co...          5
# 116  {'level': 'city', 'name': 'izmir', 'confidence...          5
# 141  {'level': 'district', 'name': 'beşiktaş', 'con...          6
# 142  {'level': 'city', 'name': 'istanbul', 'confide...          6
# 165  {'level': 'district', 'name': 'keçiören', 'con...          7
# 166  {'level': 'city', 'name': 'ankara', 'confidenc...          7
# 190  {'level': 'district', 'name': 'ataşehir', 'con...          8
# 191  {'level': 'city', 'name': 'istanbul', 'confide...          8
# 204  {'level': 'district', 'name': 'kahramankazan',...          9
# 205  {'level': 'city', 'name': 'ankara', 'confidenc...          9

# %%
# `props` kolonunu normalleştir
props_normalized = pd.json_normalize(edges_df['props'])

# Normalleştirilmiş DataFrame ile orijinal DataFrame'i birleştir
edges_df_normalized = pd.concat([edges_df, props_normalized], axis=1)

# `level` ve `name` kolonlarında benzersiz değerleri al
distinct_values = edges_df_normalized[['level', 'name']].drop_duplicates()
# Sonuçları yazdır
distinct_values[distinct_values["level"] == "city"]
# Out:
#    level      name
# 13  city    ankara
# 70  city     izmir
# 87  city  istanbul

# %%
edges_df["relation"].value_counts()
# Out:
# relation
# RATED_FOR         36709
# LOCATED_IN         4670
# CO_OCCUR           3490
# SERVES             2961
# SUITS_OCCASION      622
# HAS_AMENITY         442
# CONTRASTS           153
# IMPLIES               4
# Name: count, dtype: int64

# %% [markdown]
# ## Neo4j Package Installation

# %%
# Install required packages for Neo4j
# Run this cell first to install dependencies
# %pip install neo4j pandas
# Out:
# Requirement already satisfied: neo4j in /opt/anaconda3/lib/python3.12/site-packages (5.28.2)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.12/site-packages (from neo4j) (2024.1)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Neo4j Knowledge Graph Class Definition
#
# **Node türleri:** Restaurant, Aspect, Location, Amenity, Occasion, MenuItem
# **Relationship türleri:** RATED_FOR, SERVES, LOCATED_IN, HAS_AMENITY, SUITS_OCCASION

# %%
# ========= 5) Neo4j Knowledge Graph Builder =========
from neo4j import GraphDatabase
import logging

class Neo4jKnowledgeGraph:
    def __init__(self, uri="bolt://localhost:7687", user="neo4j", password="password"):
        """
        Initialize Neo4j connection

        Default connection assumes local Neo4j instance:
        - URI: bolt://localhost:7687
        - User: neo4j
        - Password: password (change this!)

        Make sure Neo4j is running before using this class.
        """
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def clear_database(self):
        """Clear all nodes and relationships - USE WITH CAUTION!"""
        with self.driver.session() as session:
            session.run("MATCH (n) DETACH DELETE n")
            print("Database cleared!")

    def create_constraints_and_indexes(self):
        """Create constraints and indexes for better performance"""
        with self.driver.session() as session:
            constraints_and_indexes = [
                # Constraints (ensure uniqueness)
                "CREATE CONSTRAINT restaurant_id IF NOT EXISTS FOR (r:Restaurant) REQUIRE r.id IS UNIQUE",
                "CREATE CONSTRAINT aspect_id IF NOT EXISTS FOR (a:Aspect) REQUIRE a.id IS UNIQUE",
                "CREATE CONSTRAINT location_id IF NOT EXISTS FOR (l:Location) REQUIRE l.id IS UNIQUE",
                "CREATE CONSTRAINT amenity_id IF NOT EXISTS FOR (am:Amenity) REQUIRE am.id IS UNIQUE",
                "CREATE CONSTRAINT occasion_id IF NOT EXISTS FOR (o:Occasion) REQUIRE o.id IS UNIQUE",
                "CREATE CONSTRAINT menu_id IF NOT EXISTS FOR (m:MenuItem) REQUIRE m.id IS UNIQUE",

                # Indexes for faster queries
                "CREATE INDEX restaurant_name IF NOT EXISTS FOR (r:Restaurant) ON (r.name)",
                "CREATE INDEX location_name IF NOT EXISTS FOR (l:Location) ON (l.name)",
            ]

            for cmd in constraints_and_indexes:
                try:
                    session.run(cmd)
                    print(f"✓ {cmd.split()[1]} created")
                except Exception as e:
                    print(f"⚠ {cmd.split()[1]} already exists or error: {e}")

    def extract_node_info(self, node_id):
        """Extract node type and properties from node_id like 'restaurant:name' or 'aspect:taste'"""
        if ":" not in node_id:
            return "Unknown", {"id": node_id, "name": node_id}

        node_type, name = node_id.split(":", 1)

        # Map node types to Neo4j labels
        label_map = {
            "restaurant": "Restaurant",
            "aspect": "Aspect",
            "location": "Location",
            "amenity": "Amenity",
            "occasion": "Occasion",
            "menu": "MenuItem"
        }

        label = label_map.get(node_type, "Entity")
        props = {"id": node_id, "name": name, "type": node_type}

        return label, props

    def get_stats(self):
        """Get basic statistics about the knowledge graph"""
        with self.driver.session() as session:
            # Count nodes by label
            node_counts = {}
            labels_result = session.run("CALL db.labels()")
            for record in labels_result:
                label = record[0]
                count_result = session.run(f"MATCH (n:{label}) RETURN count(n) as count")
                node_counts[label] = count_result.single()['count']

            # Count relationships by type
            rel_counts = {}
            rel_types_result = session.run("CALL db.relationshipTypes()")
            for record in rel_types_result:
                rel_type = record[0]
                count_result = session.run(f"MATCH ()-[r:{rel_type}]->() RETURN count(r) as count")
                rel_counts[rel_type] = count_result.single()['count']

            return {
                'nodes': node_counts,
                'relationships': rel_counts,
                'total_nodes': sum(node_counts.values()),
                'total_relationships': sum(rel_counts.values())
            }

    def create_node(self, node_id, additional_props=None):
        """Create a single node in Neo4j"""
        label, props = self.extract_node_info(node_id)

        if additional_props:
            props.update(additional_props)

        # Şehir isimlerini normalize et
        if 'name' in props:
            props['name'] = norm(props['name'])

        with self.driver.session() as session:
            query = f"""
            MERGE (n:{label} {{id: $id}})
            SET n += $props
            RETURN n
            """
            session.run(query, id=node_id, props=props)


    def create_relationship(self, head_id, relation, tail_id, props=None):
        """Create a relationship between two nodes"""
        # Ensure both nodes exist first
        self.create_node(head_id)
        self.create_node(tail_id)

        head_label, _ = self.extract_node_info(head_id)
        tail_label, _ = self.extract_node_info(tail_id)

        props = props or {}

        with self.driver.session() as session:
            query = f"""
            MATCH (h:{head_label} {{id: $head_id}})
            MATCH (t:{tail_label} {{id: $tail_id}})
            MERGE (h)-[r:{relation}]->(t)
            SET r += $props
            RETURN r
            """
            session.run(query, head_id=head_id, tail_id=tail_id, props=props)

    def bulk_import_edges(self, edges_df, batch_size=1000):
        """Efficiently import all edges from the DataFrame"""
        print(f"Importing {len(edges_df)} edges in batches of {batch_size}...")

        # First pass: Create all unique nodes
        unique_nodes = set()
        for _, row in edges_df.iterrows():
            unique_nodes.add(row['head'])
            unique_nodes.add(row['tail'])

        print(f"Creating {len(unique_nodes)} unique nodes...")

        with self.driver.session() as session:
            for i, node_id in enumerate(unique_nodes):
                if i % 100 == 0:
                    print(f"  Nodes created: {i}/{len(unique_nodes)}")

                label, props = self.extract_node_info(node_id)
                query = f"""
                MERGE (n:{label} {{id: $id}})
                SET n += $props
                """
                session.run(query, id=node_id, props=props)

        print("✓ All nodes created!")

        # Second pass: Create relationships in batches
        print("Creating relationships...")

        for i in range(0, len(edges_df), batch_size):
            batch = edges_df.iloc[i:i+batch_size]
            print(f"  Processing batch {i//batch_size + 1}/{(len(edges_df)-1)//batch_size + 1}")

            with self.driver.session() as session:
                for _, row in batch.iterrows():
                    head_id = row['head']
                    tail_id = row['tail']
                    relation = row['relation']
                    props = row.get('props', {})

                    # Add doc_index if available
                    if 'doc_index' in row:
                        props['doc_index'] = row['doc_index']

                    head_label, _ = self.extract_node_info(head_id)
                    tail_label, _ = self.extract_node_info(tail_id)

                    query = f"""
                    MATCH (h:{head_label} {{id: $head_id}})
                    MATCH (t:{tail_label} {{id: $tail_id}})
                    MERGE (h)-[r:{relation}]->(t)
                    SET r += $props
                    """
                    session.run(query, head_id=head_id, tail_id=tail_id, props=props)

        print("✓ All relationships created!")

# %% [markdown]
# ## Neo4j Connection Test

# %%
# Initialize the knowledge graph
kg = Neo4jKnowledgeGraph(
    uri="neo4j://127.0.0.1:7687",
    user="neo4j",
    password="12345678"  # ← bunu güçlü bir şifre ile değiştir
)

try:
    # Test connection
    print("Testing Neo4j connection...")
    stats = kg.get_stats()
    print("✓ Connected to Neo4j successfully!")
    print(f"Current database has {stats['total_nodes']} nodes and {stats['total_relationships']} relationships")

except Exception as e:
    print(f"❌ Connection failed: {e}")
    print("\nMake sure:")
    print("1. Neo4j is running")
    print("2. The password is correct")
    print("3. The URI is correct (default: bolt://localhost:7687)")
    kg = None
# Out:
# Testing Neo4j connection...
# ✓ Connected to Neo4j successfully!
# Current database has 13386 nodes and 50183 relationships

# %% [markdown]
# ## Knowledge Graph Creation and Data Import
#
# **Adımlar:**
# 1. Database schema oluşturma (constraints ve indexes)
# 2. 4522 edge'i 500'lük batch'ler halinde import etme
# 3. 2140 unique node oluşturma
# 4. 4479 relationship oluşturma
#
# **Final İstatistikler:**
# - Restaurant: 249, Aspect: 1704, Location: 24, Amenity: 6, Occasion: 5, MenuItem: 152
# - RATED_FOR: 3564, SERVES: 312, LOCATED_IN: 496, HAS_AMENITY: 44, SUITS_OCCASION: 63

# %%
# ========= 7) Import Data into Neo4j =========

if kg is not None:
    print("Setting up database schema...")

    # Create constraints and indexes
    kg.create_constraints_and_indexes()

    print(f"\nImporting {len(edges_df)} edges into Neo4j...")
    print("This may take a few minutes...")

    # Import all edges (this creates nodes and relationships)
    kg.bulk_import_edges(edges_df, batch_size=500)

    print("\n🎉 Knowledge graph created successfully!")

    # Get final statistics
    final_stats = kg.get_stats()
    print(f"\nFinal Statistics:")
    print(f"📊 Total Nodes: {final_stats['total_nodes']}")
    print(f"🔗 Total Relationships: {final_stats['total_relationships']}")
    print(f"\nNodes by type:")
    for label, count in final_stats['nodes'].items():
        print(f"  {label}: {count}")
    print(f"\nRelationships by type:")
    for rel_type, count in final_stats['relationships'].items():
        print(f"  {rel_type}: {count}")

else:
    print("❌ Skipping import - no Neo4j connection")
# Out:
# Setting up database schema...
# ✓ CONSTRAINT created
# ✓ CONSTRAINT created
# ✓ CONSTRAINT created
# ✓ CONSTRAINT created
# ✓ CONSTRAINT created
# ✓ CONSTRAINT created
# ✓ INDEX created
# ✓ INDEX created
#
# Importing 49051 edges into Neo4j...
# This may take a few minutes...
# Importing 49051 edges in batches of 500...
# Creating 13034 unique nodes...
#   Nodes created: 0/13034
#   Nodes created: 100/13034
#   Nodes created: 200/13034
#   Nodes created: 300/13034
#   Nodes created: 400/13034
#   Nodes created: 500/13034
#   Nodes created: 600/13034
#   Nodes created: 700/13034
#   Nodes created: 800/13034
#   Nodes created: 900/13034
#   Nodes created: 1000/13034
#   Nodes created: 1100/13034
#   Nodes created: 1200/13034
#   Nodes created: 1300/13034
#   Nodes created: 1400/13034
#   Nodes created: 1500/13034
#   Nodes created: 1600/13034
#   Nodes created: 1700/13034
#   Nodes created: 1800/13034
#   Nodes created: 1900/13034
#   Nodes created: 2000/13034
#   Nodes created: 2100/13034
#   Nodes created: 2200/13034
#   Nodes created: 2300/13034
#   Nodes created: 2400/13034
#   Nodes created: 2500/13034
#   Nodes created: 2600/13034
#   Nodes created: 2700/13034
#   Nodes created: 2800/13034
#   Nodes created: 2900/13034
#   Nodes created: 3000/13034
#   Nodes created: 3100/13034
#   Nodes created: 3200/13034
#   Nodes created: 3300/13034
#   Nodes created: 3400/13034
#   Nodes created: 3500/13034
#   Nodes created: 3600/13034
#   Nodes created: 3700/13034
#   Nodes created: 3800/13034
#   Nodes created: 3900/13034
#   Nodes created: 4000/13034
#   Nodes created: 4100/13034
#   Nodes created: 4200/13034
#   Nodes created: 4300/13034
#   Nodes created: 4400/13034
#   Nodes created: 4500/13034
#   Nodes created: 4600/13034
#   Nodes created: 4700/13034
#   Nodes created: 4800/13034
#   Nodes created: 4900/13034
#   Nodes created: 5000/13034
#   Nodes created: 5100/13034
#   Nodes created: 5200/13034
#   Nodes created: 5300/13034
#   Nodes created: 5400/13034
#   Nodes created: 5500/13034
#   Nodes created: 5600/13034
#   Nodes created: 5700/13034
#   Nodes created: 5800/13034
#   Nodes created: 5900/13034
#   Nodes created: 6000/13034
#   Nodes created: 6100/13034
#   Nodes created: 6200/13034
#   Nodes created: 6300/13034
#   Nodes created: 6400/13034
#   Nodes created: 6500/13034
#   Nodes created: 6600/13034
#   Nodes created: 6700/13034
#   Nodes created: 6800/13034
#   Nodes created: 6900/13034
#   Nodes created: 7000/13034
#   Nodes created: 7100/13034
#   Nodes created: 7200/13034
#   Nodes created: 7300/13034
#   Nodes created: 7400/13034
#   Nodes created: 7500/13034
#   Nodes created: 7600/13034
#   Nodes created: 7700/13034
#   Nodes created: 7800/13034
#   Nodes created: 7900/13034
#   Nodes created: 8000/13034
#   Nodes created: 8100/13034
#   Nodes created: 8200/13034
#   Nodes created: 8300/13034
#   Nodes created: 8400/13034
#   Nodes created: 8500/13034
#   Nodes created: 8600/13034
#   Nodes created: 8700/13034
#   Nodes created: 8800/13034
#   Nodes created: 8900/13034
#   Nodes created: 9000/13034
#   Nodes created: 9100/13034
#   Nodes created: 9200/13034
#   Nodes created: 9300/13034
#   Nodes created: 9400/13034
#   Nodes created: 9500/13034
#   Nodes created: 9600/13034
#   Nodes created: 9700/13034
#   Nodes created: 9800/13034
#   Nodes created: 9900/13034
#   Nodes created: 10000/13034
#   Nodes created: 10100/13034
#   Nodes created: 10200/13034
#   Nodes created: 10300/13034
#   Nodes created: 10400/13034
#   Nodes created: 10500/13034
#   Nodes created: 10600/13034
#   Nodes created: 10700/13034
#   Nodes created: 10800/13034
#   Nodes created: 10900/13034
#   Nodes created: 11000/13034
#   Nodes created: 11100/13034
#   Nodes created: 11200/13034
#   Nodes created: 11300/13034
#   Nodes created: 11400/13034
#   Nodes created: 11500/13034
#   Nodes created: 11600/13034
#   Nodes created: 11700/13034
#   Nodes created: 11800/13034
#   Nodes created: 11900/13034
#   Nodes created: 12000/13034
#   Nodes created: 12100/13034
#   Nodes created: 12200/13034
#   Nodes created: 12300/13034
#   Nodes created: 12400/13034
#   Nodes created: 12500/13034
#   Nodes created: 12600/13034
#   Nodes created: 12700/13034
#   Nodes created: 12800/13034
#   Nodes created: 12900/13034
#   Nodes created: 13000/13034
# ✓ All nodes created!
# Creating relationships...
#   Processing batch 1/99
#   Processing batch 2/99
#   Processing batch 3/99
#   Processing batch 4/99
#   Processing batch 5/99
#   Processing batch 6/99
#   Processing batch 7/99
#   Processing batch 8/99
#   Processing batch 9/99
#   Processing batch 10/99
#   Processing batch 11/99
#   Processing batch 12/99
#   Processing batch 13/99
#   Processing batch 14/99
#   Processing batch 15/99
#   Processing batch 16/99
#   Processing batch 17/99
#   Processing batch 18/99
#   Processing batch 19/99
#   Processing batch 20/99
#   Processing batch 21/99
#   Processing batch 22/99
#   Processing batch 23/99
#   Processing batch 24/99
#   Processing batch 25/99
#   Processing batch 26/99
#   Processing batch 27/99
#   Processing batch 28/99
#   Processing batch 29/99
#   Processing batch 30/99
#   Processing batch 31/99
#   Processing batch 32/99
#   Processing batch 33/99
#   Processing batch 34/99
#   Processing batch 35/99
#   Processing batch 36/99
#   Processing batch 37/99
#   Processing batch 38/99
#   Processing batch 39/99
#   Processing batch 40/99
#   Processing batch 41/99
#   Processing batch 42/99
#   Processing batch 43/99
#   Processing batch 44/99
#   Processing batch 45/99
#   Processing batch 46/99
#   Processing batch 47/99
#   Processing batch 48/99
#   Processing batch 49/99
#   Processing batch 50/99
#   Processing batch 51/99
#   Processing batch 52/99
#   Processing batch 53/99
#   Processing batch 54/99
#   Processing batch 55/99
#   Processing batch 56/99
#   Processing batch 57/99
#   Processing batch 58/99
#   Processing batch 59/99
#   Processing batch 60/99
#   Processing batch 61/99
#   Processing batch 62/99
#   Processing batch 63/99
#   Processing batch 64/99
#   Processing batch 65/99
#   Processing batch 66/99
#   Processing batch 67/99
#   Processing batch 68/99
#   Processing batch 69/99
#   Processing batch 70/99
#   Processing batch 71/99
#   Processing batch 72/99
#   Processing batch 73/99
#   Processing batch 74/99
#   Processing batch 75/99
#   Processing batch 76/99
#   Processing batch 77/99
#   Processing batch 78/99
#   Processing batch 79/99
#   Processing batch 80/99
#   Processing batch 81/99
#   Processing batch 82/99
#   Processing batch 83/99
#   Processing batch 84/99
#   Processing batch 85/99
#   Processing batch 86/99
#   Processing batch 87/99
#   Processing batch 88/99
#   Processing batch 89/99
#   Processing batch 90/99
#   Processing batch 91/99
#   Processing batch 92/99
#   Processing batch 93/99
#   Processing batch 94/99
#   Processing batch 95/99
#   Processing batch 96/99
#   Processing batch 97/99
#   Processing batch 98/99
#   Processing batch 99/99
# ✓ All relationships created!
#
# 🎉 Knowledge graph created successfully!
#
# Final Statistics:
# 📊 Total Nodes: 13386
# 🔗 Total Relationships: 50183
#
# Nodes by type:
#   Restaurant: 2339
#   Aspect: 10194
#   Location: 84
#   Amenity: 7
#   Occasion: 5
#   MenuItem: 757
#
# Relationships by type:
#   RATED_FOR: 37284
#   SERVES: 3016
#   LOCATED_IN: 5932
#   HAS_AMENITY: 443
#   SUITS_OCCASION: 627
#   CONTRASTS: 151
#   CO_OCCUR: 2726
#   IMPLIES: 4

# %% [markdown]
# ## Validation Queries and Knowledge Graph Testing

# %%
def validate_relationships(kg):
    """Neo4j Knowledge Graph üzerinde ilişkilerin doğruluğunu test eder"""
    if kg is None:
        print("❌ Neo4j bağlantısı yok")
        return

    queries = [
        {
            "name": "RATED_FOR Relationship",
            "query": """
            MATCH (r:Restaurant)-[rating:RATED_FOR]->(a:Aspect)
            RETURN r.name as restoran, a.name as aspekt, rating.sentiment as sentiment, rating.score as puan
            LIMIT 10
            """,
            "description": "RATED_FOR ilişkisi, restoranların değerlendirmelerinin doğru bağlandığını kontrol eder"
        },

        {
            "name": "LOCATED_IN Relationship",
            "query": """
            MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
            RETURN r.name as restoran, l.name as lokasyon
            LIMIT 10
            """,
            "description": "LOCATED_IN ilişkisi, restoranların doğru lokasyonlarla eşlendiğini kontrol eder"
        },

        {
            "name": "SERVES Relationship",
            "query": """
            MATCH (r:Restaurant)-[:SERVES]->(m:MenuItem)
            RETURN r.name as restoran, m.name as menu_item
            LIMIT 10
            """,
            "description": "SERVES ilişkisi, restoranların menü öğeleriyle doğru bağlandığını kontrol eder"
        },

        {
            "name": "SUITS_OCCASION Relationship",
            "query": """
            MATCH (r:Restaurant)-[:SUITS_OCCASION]->(o:Occasion)
            RETURN r.name as restoran, o.name as occasion
            LIMIT 10
            """,
            "description": "SUITS_OCCASION ilişkisi, restoranların doğru özel günlere (örneğin, romantik, aile) eşlendiğini kontrol eder"
        },

        {
            "name": "HAS_AMENITY Relationship",
            "query": """
            MATCH (r:Restaurant)-[:HAS_AMENITY]->(am:Amenity)
            RETURN r.name as restoran, am.name as amenity
            LIMIT 10
            """,
            "description": "HAS_AMENITY ilişkisi, restoranların sahip olduğu imkanların doğru bağlandığını kontrol eder"
        }
    ]

    print("🔍 İlişkiler doğrulama sorguları çalıştırılıyor...\n")

    with kg.driver.session() as session:
        for i, q in enumerate(queries, 1):
            print(f"{i}. {q['name']}")
            print(f"   {q['description']}")

            try:
                result = session.run(q['query'])
                records = list(result)

                if records:
                    print(f"   ✓ {len(records)} sonuç bulundu:")
                    for j, record in enumerate(records[:3]):  # İlk 3 sonucu göster
                        print(f"     {j+1}. {dict(record)}")
                    if len(records) > 3:
                        print(f"     ... ve {len(records) - 3} tane daha")
                else:
                    print("   ⚠ Sonuç bulunamadı")

            except Exception as e:
                print(f"   ❌ Sorgu hatası: {e}")

            print()

# Çalıştır
validate_relationships(kg)
# Out:
# 🔍 İlişkiler doğrulama sorguları çalıştırılıyor...
#
# 1. RATED_FOR Relationship
#    RATED_FOR ilişkisi, restoranların değerlendirmelerinin doğru bağlandığını kontrol eder
#    ✓ 10 sonuç bulundu:
#      1. {'restoran': 'beyzade_cafe_elmadag', 'aspekt': 'kahve kalitesi', 'sentiment': 'negative', 'puan': 0.825}
#      2. {'restoran': 'beyzade_cafe_elmadag', 'aspekt': 'ferah', 'sentiment': 'positive', 'puan': 0.94}
#      3. {'restoran': 'beyzade_cafe_elmadag', 'aspekt': 'sipariş bekletme', 'sentiment': 'negative', 'puan': 0.775}
#      ... ve 7 tane daha
#
# 2. LOCATED_IN Relationship
#    LOCATED_IN ilişkisi, restoranların doğru lokasyonlarla eşlendiğini kontrol eder
#    ✓ 10 sonuç bulundu:
#      1. {'restoran': 'cagla_cafe', 'lokasyon': 'kahramankazan'}
#      2. {'restoran': 'altin_yaprak_doner', 'lokasyon': 'kahramankazan'}
#      3. {'restoran': '19_pide_kebap_ustanin_yeri', 'lokasyon': 'kahramankazan'}
#      ... ve 7 tane daha
#
# 3. SERVES Relationship
#    SERVES ilişkisi, restoranların menü öğeleriyle doğru bağlandığını kontrol eder
#    ✓ 10 sonuç bulundu:
#      1. {'restoran': 'can_dadas_erzurum_cag_kebabi', 'menu_item': 'meze lezzeti'}
#      2. {'restoran': 'bey_aspava', 'menu_item': 'meze lezzeti'}
#      3. {'restoran': 'camlik_mangal_evi_aile_piknik_alani_serpme_kahvalti_mangal', 'menu_item': 'meze lezzeti'}
#      ... ve 7 tane daha
#
# 4. SUITS_OCCASION Relationship
#    SUITS_OCCASION ilişkisi, restoranların doğru özel günlere (örneğin, romantik, aile) eşlendiğini kontrol eder
#    ✓ 10 sonuç bulundu:
#      1. {'restoran': 'bolu_mangal_evi', 'occasion': 'aile'}
#      2. {'restoran': 'babanin_yeri_lokantasi', 'occasion': 'aile'}
#      3. {'restoran': 'adem_doruk_ivedik_balik_alabalik_lokantasi_yenimahalle', 'occasion': 'aile'}
#      ... ve 7 tane daha
#
# 5. HAS_AMENITY Relationship
#    HAS_AMENITY ilişkisi, restoranların sahip olduğu imkanların doğru bağlandığını kontrol eder
#    ✓ 10 sonuç bulundu:
#      1. {'restoran': 'bahceli_cafe_restaurant', 'amenity': 'deniz manzarası'}
#      2. {'restoran': 'big_chefs_kiyi_istanbul_subesi', 'amenity': 'deniz manzarası'}
#      3. {'restoran': 'adaturka_kafe_restoran', 'amenity': 'deniz manzarası'}
#      ... ve 7 tane daha

# %% [markdown]
# ## Kompleks Çoklu Relation Sorguları
# Bu cell'de "Ankara Beypazarı'nda çocuk bahçesi olan kebapçı" tarzı kompleks sorgular için geliştirilmiş fonksiyonlar bulunur:
#
# **Yeni özellikler:**
# - `search_restaurants_multi_criteria()`: Şehir + ilçe + menü + amenity kombinasyonları
# - `find_restaurants_with_all_criteria()`: Dictionary tabanlı esnek arama

# %%
def chatbot_query_restaurants(kg, criteria, limit=3):
    """
    Chatbot için restoran arama fonksiyonu.
    criteria dict örneği:
    {
        "city": "ankara",
        "district": "beypazarı",
        "menu": "kebap",
        "amenities": ["çocuk parkı"],
        "occasion": "romantik",
        "min_score": 0.7,
        "aspects": ["temiz", "cana yakın personel"]
    }
    """
    if kg is None:
        return [{"error": "Neo4j bağlantısı yok"}]

    with kg.driver.session() as session:
        match_clauses = ["(r:Restaurant)"]
        conditions = []
        params = {"limit": limit}

        # Şehir
        if "city" in criteria:
            match_clauses.append("(r)-[:LOCATED_IN]->(city:Location)")
            conditions.append("toLower(city.name) = $city")
            params["city"] = criteria["city"].lower()

        # İlçe
        if "district" in criteria:
            match_clauses.append("(r)-[:LOCATED_IN]->(district:Location)")
            conditions.append("toLower(district.name) = $district")
            params["district"] = criteria["district"].lower()

        # Menü
        if "menu" in criteria:
            match_clauses.append("(r)-[:SERVES]->(m:MenuItem)")
            conditions.append("toLower(m.name) CONTAINS $menu")
            params["menu"] = criteria["menu"].lower()

        # Amenity
        if "amenities" in criteria:
            for i, amenity in enumerate(criteria["amenities"]):
                match_clauses.append(f"(r)-[:HAS_AMENITY]->(a{i}:Amenity)")
                conditions.append(f"toLower(a{i}.name) CONTAINS $amenity{i}")
                params[f"amenity{i}"] = amenity.lower()

        # Occasion
        if "occasion" in criteria:
            match_clauses.append("(r)-[:SUITS_OCCASION]->(o:Occasion)")
            conditions.append("toLower(o.name) = $occasion")
            params["occasion"] = criteria["occasion"].lower()

        # Aspect (Yeni eklenen kısım)
        if "aspects" in criteria:
            for i, aspect in enumerate(criteria["aspects"]):
                match_clauses.append(f"(r)-[:RATED_FOR]->(asp{i}:Aspect)")
                conditions.append(f"toLower(asp{i}.name) CONTAINS $aspect{i}")
                params[f"aspect{i}"] = aspect.lower()

        # Min score
        if "min_score" in criteria:
            match_clauses.append("(r)-[rating:RATED_FOR]->(asp:Aspect)")
            conditions.append("rating.score >= $min_score AND rating.sentiment = 'positive'")
            params["min_score"] = criteria["min_score"]

        match_clause = "MATCH " + ", ".join(match_clauses)
        where_clause = "WHERE " + " AND ".join(conditions) if conditions else ""

        query = f"""
        {match_clause}
        {where_clause}
        OPTIONAL MATCH (r)-[rt:RATED_FOR]->(asp:Aspect)
        OPTIONAL MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
        OPTIONAL MATCH (r)-[:SERVES]->(m:MenuItem)
        OPTIONAL MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
        WHERE rt.sentiment = 'positive'
        WITH r,
             avg(rt.score) as avg_score,
             collect(DISTINCT asp.name) as aspects,
             collect(DISTINCT am.name) as amenities,
             collect(DISTINCT m.name) as menu_items,
             collect(DISTINCT o.name) as occasions
        RETURN r.name as restoran,
               round(avg_score,2) as ortalama_puan,
               aspects, amenities, menu_items, occasions
        ORDER BY ortalama_puan DESC
        LIMIT $limit
        """

        result = session.run(query, params)
        return [dict(record) for record in result]

# %%
# Test 1: Şehir ve Menü Öğesi ile Restoran Arama
criteria = {
    "city": "ankara",
    "menu": "kebap",
    "limit": 3  # LIMIT'i 5'ten 3'e düşürdük
}
result = chatbot_query_restaurants(kg, criteria)
print(result)

# Test 2: İlçe ve Olanaklar ile Arama
criteria = {
    "district": "beypazarı",
    "amenities": ["çocuk parkı"],
    "limit": 3
}
result = chatbot_query_restaurants(kg, criteria)
print(result)

# Test 3: Özel Gün ve Tat Puanına Göre Arama
criteria = {
    "city": "izmir",
    "occasion": "romantik",
    "min_score": 0.7,
    "limit": 3
}
result = chatbot_query_restaurants(kg, criteria)
print(result)

# Test 4: Aspektler ile Arama
criteria = {
    "aspects": ["temiz", "cana yakın personel"],
    "min_score": 0.7,
    "limit": 3
}
result = chatbot_query_restaurants(kg, criteria)
print(result)
# Out:
# [{'restoran': 'oz_dedem_pide_kebap_salonu_selahattin_ustanin_yeri_sincanda_baska_subem_yoktursincan_pide_kebap', 'ortalama_puan': 0.89, 'aspects': ['yüksek fiyat', 'hızlı servis', 'ilgili personel', 'güler yüzlü personel', 'samimi ortam', 'makul fiyat', 'hijyen', 'yardımsever personel', 'usta ustalığı'], 'amenities': [], 'menu_items': ['kebap lezzeti'], 'occasions': ['aile']}, {'restoran': 'baglum_halil_ibrahim_sofrasi', 'ortalama_puan': 0.88, 'aspects': ['mantar', 'kalite', 'uygun fiyat', 'fiyat-performans', 'temizlik', 'ikramlar', 'lezzet', 'güler yüzlü', 'gecikme', 'ilgili', 'misafirperver', 'yanlış ürün', 'boğucu', 'bol ikram', 'hijyen'], 'amenities': [], 'menu_items': ['kebap'], 'occasions': []}, {'restoran': 'mis_gaziantep_pide_ve_kebap_salonu', 'ortalama_puan': 0.87, 'aspects': ['lezzetli yemek', 'temiz', 'mutfak hijyeni', 'beyti', 'uygun fiyat', 'yavaş servis', 'eksik sipariş', 'adana kebabı', 'yanlış sipariş', 'istikrarsız hizmet kalitesi', 'nezih ortam', 'doyurucu porsiyon', 'çeşitli kebap lahmacun pide', 'aile mekanı'], 'amenities': [], 'menu_items': ['kebap'], 'occasions': ['aile']}]
# []
# [{'restoran': 'dut_restaurant_cafe_bar', 'ortalama_puan': 0.87, 'aspects': ['ambiyans', 'şık dekorasyon', 'ilgili personel', 'güler yüzlü personel', 'cheesecake', 'konum', 'lezzetli yemekler', 'menü çeşitliliği', 'köz patlıcanlı yemekler', 'gün batımı manzarası', 'kokteyller', 'sahil kenarı', 'romantik atmosfer', 'ahşap detaylar', 'loş aydınlatma', 'farklı oturma seçenekleri'], 'amenities': ['bahçe'], 'menu_items': ['pizza'], 'occasions': ['romantik']}, {'restoran': 'careme_restaurant', 'ortalama_puan': 0.86, 'aspects': ['ambiyans', 'deniz manzarası', 'ilgili hizmet', 'yemek lezzeti', 'mezeler', 'kaliteli hizmet', 'makul fiyatlar', 'güler yüzlü hizmet', 'somon', 'evlilik teklifi mekanı', 'dana antrikot', 'cennet hanım', 'özel gün mekanı', 'mantarlı tavuk', 'kadir bey', 'rezervasyon yardımı', 'loş ışıklandırma', 'yemek sunumu', 'piyano müziği', 'misafir ihtiyaçlarına özen', 'tahinli sufle', 'romantik ortam'], 'amenities': ['deniz manzarası'], 'menu_items': [], 'occasions': ['romantik']}, {'restoran': 'the_guru_urla', 'ortalama_puan': 0.85, 'aspects': ['ambiyans', 'kaburga', 'huzurlu ortam', 'canlı müzik', 'özenli hizmet', 'misafirperverlik', 'özel günler için uygun', 'serpme kahvaltı', 'lezzetli yemekler', 'makul fiyatlar', 'çalışanlar', 'samimi hizmet', 'kokteyller', 'türk mutfağı lezzetleri', 'modern dokunuşlar', 'mantar kebabı', 'doğal atmosfer', 'ilgiyle yaklaşma', 'üstün hizmet', 'romantik ortam', 'dj performansları', 'güleryüz'], 'amenities': ['canlı müzik'], 'menu_items': ['pizza'], 'occasions': ['romantik']}]
# [{'restoran': 'bereket_doner_ankara_sincan_yenikent', 'ortalama_puan': 0.86, 'aspects': ['iskender', 'temizlik', 'temiz mekan', 'hoş atmosfer', 'ilgili personel', 'nezih ortam', 'hatay usulü iskender'], 'amenities': [], 'menu_items': ['dürüm', 'soğuk dürüm'], 'occasions': []}, {'restoran': 'kazan_iskembe_pide_salonu', 'ortalama_puan': 0.83, 'aspects': ['kelle paça çorbası', 'güleryüzlü hizmet', '24 saat açık', 'uygun fiyatlar', 'işkembe çorbası', 'ucuz ve kaliteli', 'tereyağlı işkembe', 'gece açık olması'], 'amenities': [], 'menu_items': [], 'occasions': []}, {'restoran': 'buyuk_beykoz_balikcisi', 'ortalama_puan': 0.83, 'aspects': ['karides', 'uygun fiyatlar', 'ilgili personel', 'güler yüzlü personel', 'palamut', 'hamsi tava', 'ucuz fiyatlar', 'lüfer', 'işletmecilik tarzı', 'mevsimlik balık çeşitliliği', 'tereyağlı karides', 'sosyal tesis fiyatları', 'güveçte karides'], 'amenities': [], 'menu_items': ['taze balık', 'lezzetli balık', 'hamur gibi pişmiş balık', 'balık ekmek arası'], 'occasions': []}]

# %%
def format_chatbot_response(results):
    if not results:
        return "⚠ Hiç uygun mekan bulunamadı."

    cevap = ["✨ Önerilen mekanlar:"]

    for i, r in enumerate(results, 1):
        # Başlangıç: Restoran adı ve puanı
        line = f"{i}. {r.get('restoran', 'Bilinmeyen Restoran')} (Puan: {r.get('ortalama_puan', 'Bilgi yok')})"

        # Aspects (Öne çıkan özellikler)
        aspects = r.get("aspects", [])
        if aspects:
            line += f" | Öne çıkan: {', '.join(aspects[:3])}"

        # İmkanlar (amenities)
        amenities = r.get("amenities", [])
        if amenities:
            line += f" | İmkanlar: {', '.join(amenities)}"

        # Uygunluk (occasions)
        occasions = r.get("occasions", [])
        if occasions:
            line += f" | Uygun: {', '.join(occasions)}"

        # Menü (menu_items)
        menu_items = r.get("menu_items", [])
        if menu_items:
            line += f" | Menü: {', '.join(menu_items[:3])}"

        # Satıra eklenen restoran bilgilerini cevap listesine ekliyoruz
        cevap.append(line)

    return "\n".join(cevap)

# %%
def get_restaurant_summary(restaurant_name, data):
    # Veriyi filtreleyerek restoranın özetini bulma
    restaurant_summary = data[data['Mekan_Adı'] == restaurant_name]['Özet'].values
    return restaurant_summary[0] if len(restaurant_summary) > 0 else "Özet bulunamadı"

def format_chatbot_response(results, data):
    if not results:
        return "⚠ Hiç uygun mekan bulunamadı."

    cevap = ["✨ Önerilen mekanlar:"]

    for i, r in enumerate(results, 1):
        # Başlangıç: Restoran adı ve puanı
        line = f"{i}. {r.get('restoran', 'Bilinmeyen Restoran')} (Puan: {r.get('ortalama_puan', 'Bilgi yok')})"

        # Özet bilgisi (data dosyasından alıyoruz)
        restoran_ozet = get_restaurant_summary(r.get('restoran'), data)
        line += f" | Özet: {restoran_ozet}"

        # İmkanlar (amenities)
        amenities = r.get("amenities", [])
        if amenities:
            line += f" | İmkanlar: {', '.join(amenities)}"

        # Uygunluk (occasions)
        occasions = r.get("occasions", [])
        if occasions:
            line += f" | Uygun: {', '.join(occasions)}"

        # Menü (menu_items)
        menu_items = r.get("menu_items", [])
        if menu_items:
            line += f" | Menü: {', '.join(menu_items[:3])}"

        # Satıra eklenen restoran bilgilerini cevap listesine ekliyoruz
        cevap.append(line)

    return "\n".join(cevap)

results = [
    {'restoran': 'öz_dedem_pide_kebap_salonu', 'ortalama_puan': 0.89, 'aspects': ['yüksek fiyat', 'hızlı servis'], 'amenities': [], 'menu_items': ['kebap'], 'occasions': ['aile']},
    {'restoran': 'baglum_halil_ibrahim_sofrasi', 'ortalama_puan': 0.88, 'aspects': ['mantar', 'kalite'], 'amenities': [], 'menu_items': ['kebap'], 'occasions': []},
    {'restoran': 'mis_gaziantep_pide_ve_kebap_salonu', 'ortalama_puan': 0.87, 'aspects': ['lezzetli yemek', 'temiz'], 'amenities': [], 'menu_items': ['beyti'], 'occasions': ['aile']}
]

# Formatlı cevap
formatted_response = format_chatbot_response(results, data)
print(formatted_response)
# Out:
# ✨ Önerilen mekanlar:
# 1. öz_dedem_pide_kebap_salonu (Puan: 0.89) | Özet: Özet bulunamadı | Uygun: aile | Menü: kebap
# 2. baglum_halil_ibrahim_sofrasi (Puan: 0.88) | Özet: Bu yorumların genelinde restoranın öne çıkan özellikleri şunlar:
#
# **Lezzet:** Yemeklerin kalitesi ve lezzeti sıkça övülüyor. Özellikle pide, lahmacun, kebap çeşitleri ve ikramlar (çiğ köfte, mantar, salata) beğeniliyor.
# **Hizmet Kalitesi:** Çalışanların güler yüzlü, ilgili ve misafirperver olduğu vurgulanıyor. İkramların bol olması da dikkat çekiyor.
# **Temizlik ve Hijyen:** Restoranın temizliği ve hijyeni müşteriler tarafından takdir ediliyor.
# **Fiyat-Performans Dengesi:** Yemeklerin lezzeti göz önüne alındığında fiyatların uygun olduğu belirtiliyor.
#
# **Olumsuz Yönler:** Bazı yorumlarda siparişlerde gecikme, yanlış ürün gönderimi ve mekanın biraz boğucu olması gibi eleştiriler yer alıyor. Ancak bu şikayetler genel memnuniyeti gölgelemiyor.
#
# Sonuç olarak, restoran lezzetli yemekleri, kaliteli hizmeti ve uygun fiyatlarıyla Bağlum bölgesinde tercih edilen bir mekan olarak öne çıkıyor. | Menü: kebap
# 3. mis_gaziantep_pide_ve_kebap_salonu (Puan: 0.87) | Özet: Mis Gaziantep, Sincan'da ailecek gidilebilecek temiz ve nezih bir mekan olarak öne çıkıyor. Müşteriler genellikle kebap, lahmacun ve pide çeşitlerini övgüyle anlatıyorlar. Özellikle Adana kebabı, beyti ve lavaşlı döner gibi lezzetler sıklıkla tavsiye ediliyor. Fiyatların uygun olması ve porsiyonların doyurucu olması da müşteri memnuniyetini artırıyor.
#
# Bununla birlikte bazı yorumlarda servis hızının yavaşlaması, siparişlerde eksiklikler veya yanlışlıklar yaşanması gibi olumsuz deneyimler de dile getiriliyor. Ayrıca mutfak hijyeni konusunda eleştiriler bulunuyor. Genel olarak Mis Gaziantep lezzetli yemekleri ve uygun fiyatlarıyla tercih edilen bir mekan olsa da hizmet kalitesinin istikrarlı olması için bazı iyileştirmeler yapılması gerekiyor. | Uygun: aile | Menü: beyti

# %% [markdown]
# ## Kompleks Sorgu Test Örnekleri

# %%
print("🎯 CHATBOT TABANLI ÇOKLU RELATION TESTLERİ")
print("=" * 60)

# Neo4j bağlantısı var mı kontrol edelim
if not kg:
    print("❌ Neo4j bağlantısı yok!")
else:
    print("✅ Neo4j bağlantısı aktif")

# Test 1: Ankara Beypazarı'nda çocuk parkı olan kebapçı
print("\n🔥 TEST 1: Ankara Beypazarı'nda çocuk parkı olan kebapçı")
criteria1 = {
    "city": "ankara",
    "district": "beypazarı",
    "menu": "kebap",
    "amenities": ["çocuk parkı"]
}
results1 = chatbot_query_restaurants(kg, criteria1, limit=5) if kg else []
if results1:
    print(format_chatbot_response(results1, data))  # Sonuçları formatla ve göster
else:
    print("❌ Bu kriterlere uygun restoran bulunamadı.")
    print("💡 Daha az kriter ile tekrar deneyin.")

# Test 2: Ankara'da bahçeli restoranlar
print("\n🔥 TEST 2: Ankara'da bahçeli restoranlar")
criteria2 = {
    "city": "ankara",
    "amenities": ["bahçe"]
}
results2 = chatbot_query_restaurants(kg, criteria2, limit=5) if kg else []
if results2:
    print(format_chatbot_response(results2, data))  # Sonuçları formatla ve göster
else:
    print("❌ Ankara'da bahçeli restoran bulunamadı.")

# Test 3: İzmir Konak'ta pizza mekanı
print("\n🔥 TEST 3: İzmir Konak'ta pizza mekanı")
criteria3 = {
    "city": "izmir",
    "district": "konak",
    "menu": "pizza"
}
results3 = chatbot_query_restaurants(kg, criteria3, limit=5) if kg else []
if results3:
    print(format_chatbot_response(results3, data))  # Sonuçları formatla ve göster
else:
    print("❌ İzmir Konak'ta pizza mekanı bulunamadı.")

# Test 4: İstanbul'da romantik kebapçı
print("\n🔥 TEST 4: İstanbul'da romantik kebapçı")
criteria4 = {
    "city": "istanbul",
    "menu": "kebap",
    "occasion": "romantik"
}
results4 = chatbot_query_restaurants(kg, criteria4, limit=5) if kg else []
if results4:
    print(format_chatbot_response(results4, data))  # Sonuçları formatla ve göster
else:
    print("❌ İstanbul'da romantik kebapçı bulunamadı.")

# Test 5: İzmir'de yüksek puanlı pizzacılar
print("\n🔥 TEST 5: İzmir'de yüksek puanlı pizzacılar")
criteria5 = {
    "city": "izmir",
    "menu": "pizza",
    "min_score": 0.8
}
results5 = chatbot_query_restaurants(kg, criteria5, limit=5) if kg else []
if results5:
    print(format_chatbot_response(results5, data))  # Sonuçları formatla ve göster
else:
    print("❌ İzmir'de yüksek puanlı pizzacılar bulunamadı.")

# Test 6: İstanbul'da romantik kebapçı ve temiz/cana yakın personel
print("\n🔥 TEST 6: İstanbul'da temiz burgerci")
criteria_aspects = {
    "city": "istanbul",
    "menu": "burger",
    "aspects": ["temiz"]
}
results_aspects = chatbot_query_restaurants(kg, criteria_aspects, limit=5) if kg else []
if results_aspects:
    print(format_chatbot_response(results_aspects, data))  # Sonuçları formatla ve göster
else:
    print("❌ İstanbul'da belirtilen özelliklerde restoran bulunamadı.")
    print("💡 Daha az kriter ile tekrar deneyin.")
# Out:
# 🎯 CHATBOT TABANLI ÇOKLU RELATION TESTLERİ
# ============================================================
# ✅ Neo4j bağlantısı aktif
#
# 🔥 TEST 1: Ankara Beypazarı'nda çocuk parkı olan kebapçı
# ❌ Bu kriterlere uygun restoran bulunamadı.
# 💡 Daha az kriter ile tekrar deneyin.
#
# 🔥 TEST 2: Ankara'da bahçeli restoranlar
# ✨ Önerilen mekanlar:
# 1. koy_bahcesi (Puan: 0.88) | Özet: Bu yorumların özeti şu şekilde olabilir:
#
# **Köy Bahçesi**, genel olarak **güzel bir mekan** olarak değerlendiriliyor. Özellikle **açık havada kahvaltı yapılabilecek ferah bahçesi, çocuk oyun alanları ve otantik atmosferi** beğeniliyor. Çalışanların çoğu **güler yüzlü ve ilgili** bulunuyor.
#
# Ancak bazı önemli eksiklikler de vurgulanıyor:
#
# - **Kahvaltılık ürünlerin kalitesi ve çeşidi** yetersiz bulunmuş, özellikle peynirler, reçeller ve domates/salatalık gibi temel malzemelerin lezzetli olmadığı belirtiliyor.
# - **Servis hızı yavaş**, siparişler gecikiyor ve bazı ürünler (örneğin gözleme) saatlerce bekletmek zorunda kalınıyor.
# - **Fiyatlar yüksek** bulunuyor, özellikle semaver çayı gibi basit içeceklerin ücretleri eleştiriliyor. Kahvaltıda kişi başı 700 TL ödeyen müşteriler doymadıklarını belirtiyorlar.
# - **Yemeklerin lezzeti de tartışmalı**, bazı yemekler beğenilirken (karışık pide, pizza) bazıları (hamburger, lahmacun) vasat veya kötü bulunmuş.
#
# **Olumsuz yorumlarda sıkça dile getirilen noktalar:**
#
# * **Hijyen sorunları**: Tuvaletlerin kullanılamaz durumda olduğu ve mutfakta bim poşetiyle girildiği iddia ediliyor.
# * **Personel davranışları**: Bazı garsonların kaba, ilgisiz veya müşteriye ters davrandığı belirtiliyor.
# * **Menü eksiklikleri**: Gittiklerinde menüdeki birçok ürünün bulunmadığı söyleniyor.
#
# **Sonuç olarak**, Köy Bahçesi güzel bir mekan olmasına rağmen, hizmet kalitesi ve lezzet konusunda ciddi sorunlar yaşandığı anlaşılıyor. Fiyat-performans dengesi de müşterileri memnun etmiyor. Bu eksikliklerin giderilmesi durumunda daha başarılı olabilir.
#
# **Not:** Yorumlarda bahsedilen bazı iddialar (örneğin tuvalet hijyeni, mutfakta poşet kullanımı) doğrulanması gereken konular olup, mekanın yetkililerinden açıklama beklenebilir. | İmkanlar: bahçe | Menü: lezzetli pide, lezzetli pizza, vasat hamburger
# 2. isirgan_sirdan_mumbar_kelle (Puan: 0.87) | Özet: Bu yorumlar, restoranın **geleneksel sakatat ve et yemeklerinde uzmanlaştığı** yönünde genel bir izlenim veriyor. Özellikle kelle paça, kokoreç, mumbar gibi lezzetler sıklıkla övülüyor. Müşteriler, yemeklerin tazeliği, lezzeti ve porsiyonlarının doyurucu olmasından memnun görünüyorlar.
#
# Restoranın **samimi ve sıcak bir atmosferi** olduğu da vurgulanıyor. Garsonların ilgi ve alakası, aile ortamı hissiyatı ve güler yüzlü hizmet müşteriler tarafından takdir ediliyor. Ayrıca bazı yorumlarda açık havada yemek yiyebileceğiniz bahçenin de güzelliği belirtiliyor.
#
# Ancak restoranın **fiyatları konusunda eleştiriler** mevcut. Bazı müşteriler, özellikle lahmacunların küçük boyutuna rağmen yüksek fiyatını ve menüdeki fiyat farklarını eleştiriyorlar.
#
# Ayrıca hijyen konusunda da bazı şikayetler var. Açıkta servis edilen kaşık-çatal gibi malzemelerin temizliği ve ayranın ekşimesi gibi durumlar müşterileri rahatsız etmiş. Bu konular restoran tarafından dikkate alınarak iyileştirilmelidir.
#
# Sonuç olarak, **geleneksel lezzetleri sevenler için iyi bir seçenek** olabilecek bu restoran, hijyen ve fiyat politikalarında bazı iyileştirmeler yaparsa daha geniş bir müşteri kitlesine hitap edebilir. | İmkanlar: bahçe | Uygun: aile | Menü: küçük lahmacun
# 3. marrakesh_cafe (Puan: 0.87) | Özet: Marrakesh Cafe, Pursaklar bölgesinde öne çıkan bir mekan olarak dikkat çekiyor. Genellikle **kahvaltı ve çay** seçenekleriyle övülen mekan, özellikle ailecek vakit geçirmek için uygun bir ortam sunuyor.
#
# Mekanın **atmosferi** güzel bulunuyor; açık alanları ve bahçe düzenlemesi müşteriler tarafından beğeniliyor. Ancak, bazı yorumlarda **hizmet kalitesi** eleştiriliyor. Özellikle garsonların ilgisizliği, siparişlerin geç gelmesi ve menüdeki ürünlerin eksikliği sıkça dile getirilen sorunlar arasında.
#
# Kahvaltı konusunda da karışık yorumlar mevcut. Bazı müşteriler kahvaltının lezzetli ve taze olduğunu belirtirken, bazıları ise **fiyat-performans dengesinin** iyi olmadığını düşünüyor. Özellikle serpme kahvaltıların fiyatlarının yüksek olduğu ve porsiyonların küçük olduğu vurgulanıyor.
#
# Kahve konusunda da eleştiriler mevcut. Bazı müşteriler kahve çeşitlerinin lezzetsiz olduğunu, bazıları ise baristaların deneyim eksikliği nedeniyle yanlış içecekler getirdiğini belirtiyor.
#
# Mekanın **temizlik ve hijyen** konusundaki durumu da tartışmalı. Tuvaletlerin temiz olmadığına dair yorumlar bulunuyor. Ayrıca, sigara içen müşterilerin açık alanda bile yoğun duman oluşturduğu ifade ediliyor.
#
# Sonuç olarak, Marrakesh Cafe'nin güzel bir atmosferi ve bazı lezzetli seçenekleri olsa da hizmet kalitesi, fiyat politikası ve hijyen konusunda iyileştirmeler yapması gerekiyor. Müşteri memnuniyetini artırmak için bu alanlara odaklanması önemli olacaktır. | İmkanlar: bahçe | Uygun: aile
# 4. nefis_bahce (Puan: 0.87) | Özet: Restoranın öne çıkan özellikleri şunlar:
#
# - **Doğayla iç içe huzurlu bir ortam:** Kuş sesleri eşliğinde yeşillikler içinde kahvaltı yapma imkanı sunuyor.
# - **Güler yüzlü ve samimi hizmet:** Çalışanların sıcakkanlılığı ve misafirperverliği sıkça vurgulanıyor. Özellikle işletme sahipleri Filiz Hanım ve eşi övgü alıyor.
# - **Lezzetli ve kaliteli yemekler:** Kahvaltıda özellikle sucuk, menemen, kuymak, reçeller ve semaver çayı beğeniliyor.
# - **Temizlik ve düzen:** Mekanın temizliği ve bakımlı bahçesi müşteriler tarafından takdir ediliyor.
#
# **Olumsuz yönleri ise şunlar:**
#
# - **Fiyatların yüksek olması:** Bazı müşteriler kahvaltı fiyatlarının pahalı olduğunu düşünüyor.
# - **Servis gecikmeleri:** Yoğun saatlerde servis yavaşlayabiliyor ve bu durum bazı müşterileri rahatsız ediyor.
# - **Kahvaltı çeşitliliğinin sınırlı olması:** Bazı kişiler serpme kahvaltının kişi başı sunulması zorunluluğunu veya sıcak ürünlerin yetersizliğini eleştiriyor.
#
# Genel olarak, restoranın artıları ağır basıyor ve müşterilerin çoğu memnun ayrılıyor. Ancak fiyatlar ve servis konusunda dikkatli olunması gerekiyor. | İmkanlar: bahçe
# 5. mutlu_kebap (Puan: 0.86) | Özet: Mutlu Kebap, özellikle lezzetli kuzu etleriyle öne çıkan bir mekan olarak değerlendirilebilir. Müşteriler tarafından sıklıkla vurgulanan noktalar şunlar:
#
# - **Et Kalitesi:** Kuzu eti, pirzola ve köftelerin mükemmel lezzeti birçok yorumda övgüyle bahsediliyor. Etin doğal ve kaliteli olduğu belirtiliyor.
# - **Ortam:** Bahçesi ağaçlarla çevrili, huzurlu ve nezih bir atmosfer sunuyor. Yazın serin, kışın şömine başında keyifli vakit geçirme imkanı sağlıyor.
# - **Fiyat Performans:** Et fiyatlarının makul olduğu ve porsiyonların doyurucu olduğu belirtiliyor. Ancak bazı yorumlarda yan ürünlerin (salata, yoğurt) pahalı olduğu ifade ediliyor.
# - **Hizmet Kalitesi:** Genel olarak garsonların güler yüzlü ve ilgili olduğu vurgulanıyor. Ancak bazı müşteriler hizmet kalitesinin düştüğünü belirtiyor.
#
# Olumsuz yorumlarda ise fiyatların yüksekliği, menü eksikliği, yan ürünlerin ücretli olması ve bazen hizmet kalitesindeki dalgalanmalar eleştiriliyor.
#
# Sonuç olarak Mutlu Kebap, özellikle lezzetli kuzu eti yemek isteyenler için tercih edilebilecek bir mekan ancak yan ürünlerin ücretli olması ve fiyatların yüksekliği dikkate alınmalıdır. | İmkanlar: bahçe
#
# 🔥 TEST 3: İzmir Konak'ta pizza mekanı
# ✨ Önerilen mekanlar:
# 1. la_fourmi_restaurant (Puan: 0.84) | Özet: La Fourmi Alsancak, İzmir'in popüler ve nezih restoranlarından biri olarak öne çıkıyor. Müşteriler genel olarak yemeklerin lezzetini, porsiyon büyüklüğünü ve sunumunu övgüyle anlatıyorlar. Özellikle pizzaları, makarnaları, et yemekleri (bonfile, ciğer kebap) ve başlangıç tabağı öneriliyor.
#
# Mekanın atmosferi de sıkça övülüyor; şık dekorasyon, rahat oturma düzeni ve canlı müzik seçenekleriyle romantik akşamlar veya özel günler için ideal bir ortam sunuyor. Çalışanların güler yüzlü ve ilgili hizmetleri de müşteri memnuniyetini artırıyor.
#
# Fiyatlar genel olarak bu kalitede bir restorana göre makul bulunuyor, ancak bazı müşteriler özellikle kokteyllerin fiyatının yüksek olduğunu belirtiyor. Vale hizmeti sunulması da park sorunu yaşayanlar için büyük avantaj sağlıyor.
#
# Ancak bazı olumsuz geri bildirimler de mevcut. Yemeklerin lezzetine rağmen porsiyonların küçük olduğu, servis kalitesinin zaman zaman düştüğü ve gürültülü müzik nedeniyle sohbetin zorlaştığı eleştirileri yapılıyor. Ayrıca bir müşteri kırık tabakla servis edildiğini belirtmiş.
#
# Genel olarak La Fourmi Alsancak, lezzetli yemekler, şık atmosfer ve iyi hizmet sunan bir restoran olarak öne çıkıyor. Ancak bazı küçük eksiklikleri göz önünde bulundurarak rezervasyon yapmadan önce menü ve ambiyans hakkında detaylı bilgi almak faydalı olabilir. | İmkanlar: canlı müzik | Uygun: romantik | Menü: pizza
# 2. favino_alsancak (Puan: 0.81) | Özet: Favino Alsancak, Gül Sokak'ta bulunan samimi ve butik bir restoran olarak öne çıkıyor. Müşteriler genellikle **lezzetli yemekleri**, özellikle **pizzaları, makarnaları, tapasları ve deniz ürünleri** ile ilgili olumlu yorumlar yapıyor. Restoranın **atmosferi** sıcak, rahat ve romantik olarak nitelendiriliyor; müzik seçimi de keyif katıyor.
#
# Personelin **güler yüzlü, ilgili ve hızlı servisi** müşteriler tarafından sıklıkla övülüyor. Menü çeşitliliği zengin bulunuyor ve birçok kişi restoranı "özel günler" için ideal bir tercih olarak görüyor. Şarap menüsü de geniş ve beğeniliyor. Fiyatlar Alsancak bölgesi ortalamasında değerlendiriliyor, bazıları uygun bulurken bazıları biraz yüksek olduğunu düşünüyor.
#
# Ancak, birkaç olumsuz yorum da mevcut. Bazı müşteriler yemeklerin lezzetinden memnun kalmamış veya servis konusunda sorun yaşamış. Ayrıca, bir müşteri **alkol servisiyle ilgili kaba bir davranış** nedeniyle hayal kırıklığına uğramış. Genel olarak Favino Alsancak, lezzetli yemekleri ve samimi atmosferiyle öne çıkan bir mekan olarak değerlendirilebilir, ancak bazı olumsuz deneyimler de göz ardı edilmemeli. | Uygun: romantik | Menü: pizza
#
# 🔥 TEST 4: İstanbul'da romantik kebapçı
# ✨ Önerilen mekanlar:
# 1. roof_mezze_360_restaurant (Puan: 0.86) | Özet: Roof Mezze 360, İstanbul'un muhteşem manzarası eşliğinde unutulmaz bir yemek deneyimi sunan bir restoran olarak öne çıkıyor. Müşteriler özellikle Boğaz ve Ayasofya manzarasının nefes kesici olduğunu vurguluyorlar. Restoranın mezeleri, ana yemekleri (özellikle kuzu pirzola ve kebap) ve tatlıları büyük beğeni topluyor. Personel ise genel olarak çok ilgili, nazik ve profesyonel bulunuyor; özellikle İbrahim, Yunus, Ilyas ve Serhat gibi garsonların hizmet kalitesi sıklıkla övülüyor. Atmosferin rahatlatıcı ve samimi olduğu belirtiliyor, canlı müzik ve gün batımı manzarası da deneyimi daha özel kılıyor. Fiyatlar biraz yüksek olsa da sunulan kalite ve deneyim karşılığını veriyor. Glutensiz seçeneklerin de mevcut olması restoranı daha geniş bir kitleye hitap ediyor.
#
# Özetle Roof Mezze 360, İstanbul'da romantik bir akşam yemeği, özel gün kutlamaları veya sadece şehrin büyüleyici manzarasını izlemek isteyenler için mükemmel bir tercih olarak öne çıkıyor. | İmkanlar: canlı müzik | Uygun: romantik | Menü: kebap
# 2. arca_restaurant_grill (Puan: 0.84) | Özet: Arça Restaurant hakkında yapılan yorumlar genel olarak olumlu yönde.
#
# **Öne çıkan özellikler:**
#
# * **Yemek Kalitesi:** Mezeler, kebaplar (özellikle şaşlık), pide ve tatlılar (baklava, sufle) sıklıkla övülen lezzetler arasında. Humus, küşleme ve gavurdağı salatası da beğenilen seçenekler.
# * **Servis ve Personel:** Çalışanların güler yüzlü, ilgili ve hızlı hizmetleri müşteriler tarafından takdir ediliyor. Özellikle Meryem Hanım, Emir Bey, Fatih Bey, Şule Hanım ve Murat Büyükkeskin gibi isimler sıklıkla teşekkür edilerek anılıyor.
# * **Ambiyans:** Manzara (Haliç), loş aydınlatma ve müzikler sayesinde romantik bir atmosfer sunan mekan, özel günler için ideal olarak görülüyor.
#
# **Eleştiriler:**
#
# * **Fiyatlar:** Bazı müşteriler fiyatların yüksek olduğunu belirtiyor, ancak genel olarak lezzet ve hizmet kalitesiyle orantılı olduğu düşünülüyor.
# * **Çay Ücreti:** Çaya ücret alınması bazı müşterileri rahatsız etmiş.
# * **Servis Hızı:** Yoğun saatlerde servis yavaşlayabiliyor.
#
# **Genel Değerlendirme:** Arça Restaurant, lezzetli yemekleri, kaliteli hizmeti ve şık ambiyansı ile İstanbul'da akşam yemeği için tercih edilebilecek bir mekan olarak öne çıkıyor. Fiyatlar biraz yüksek olsa da müşteriler genel olarak memnun kalıyor.
#
# **Not:** Yorumlarda "Murat Bey"den bahsedilmiş ancak hangi Murat Bey olduğu net değil (restoran müdürü mü, yoksa başka bir çalışan mı?). Bu konuda daha fazla bilgiye ihtiyaç var. | Uygun: romantik | Menü: kebap
# 3. papuli_restaurant (Puan: 0.83) | Özet: Papuli Restaurant, İstanbul'un Küçükçekmece Gölü kıyısında konumlanan bir mekandır. **Manzara** ve **atmosfer** en çok vurgulanan özelliklerinden biri; birçok yorumda gölün huzurlu manzarası ve doğayla iç içe ortamın keyifli olduğu belirtiliyor. Özellikle akşamüstü gün batımı, romantik bir atmosfer yaratıyor.
#
# **Yemekler** konusunda ise karışık görüşler mevcut. Bazı müşteriler **mezelerin lezzetli**, özellikle pastırmalı humusu ve soğan sarması gibi seçenekleri övdü. Ancak et yemeklerinin (karışık ızgara, Adana kebap) bazı yorumlarda kuru veya vasat olarak değerlendirildiği görülüyor. Lahmacun ise eleştiri konusu olmuş. Fiyat-performans dengesi de tartışılıyor; bazı müşteriler pahalı bulurken, manzara ve ortamı göz önüne alarak makul bulduğunu belirtiyor.
#
# **Hizmet** konusunda da karışık yorumlar var. Bazı müşteriler garsonların ilgili ve güleryüzlü olduğunu vurgularken, diğerleri ilgisizlik ve kabalık yaşadıklarını dile getiriyor. Özellikle bira içen müşterilere daha az ilgi gösterildiği iddia ediliyor.
#
# **Müzik** de öne çıkan bir özellik; özellikle Çiğdem Hanım'ın ses performansı ve repertuvarı büyük beğeni topluyor. Hafta sonları canlı müzikle eğlenceli bir atmosfer yaratılıyor.
#
# **Tuvaletler** ise neredeyse tüm olumsuz yorumlarda eleştiri konusu olmuş. Temizlik ve bakımsızlık nedeniyle müşteriler rahatsız olmuş. Bu durum, mekanın genel puanını düşüren önemli bir faktör olarak öne çıkıyor.
#
# Özetle Papuli Restaurant, güzel manzarası, canlı müziği ve bazı lezzetli mezeleriyle dikkat çekiyor ancak tuvaletlerin durumu, hizmet kalitesindeki dalgalanmalar ve et yemeklerinin tutarlılığı konusunda eleştiriler alıyor. Fiyatlar da yüksek bulunabiliyor. | İmkanlar: canlı müzik | Uygun: romantik | Menü: adana kebap
# 4. fb_culture (Puan: 0.8) | Özet: F&B Culture, İstanbul'un Galata bölgesinde konumlanan, hem turistlerin hem de yerlilerin tercih ettiği bir restoran olarak öne çıkıyor. **Öne çıkan özellikleri şunlar:**
#
# - **Lezzet ve Sunum:** Türk mutfağının klasik lezzetlerini modern bir yorumla sunan restoran, özellikle balık yemekleri (levrek rulosu, beyaz balığı pancar soslu patatesle), kebap çeşitleri (dana kaburgası, kuzu eti) ve mezeleriyle dikkat çekiyor. Yemeklerin tazeliği ve özenli sunumu sıklıkla övülüyor.
# - **Atmosfer:** Hem iç mekanın rahat pub tarzı hem de Galata Kulesi manzaralı teras, restoranı hem romantik akşam yemekleri hem de arkadaşlarla sohbet için ideal kılıyor. Cazibesi ve davetkar ortamı misafirler tarafından beğeniliyor.
# - **Hizmet:** Personelin sıcakkanlılığı, hızlı ve özenli hizmeti müşterilerden tam not alıyor. Özellikle Ömer, Engin ve Karabayır gibi çalışanlar ismiyle anılıyor. İspanyolca konuşan personel de turistler için avantaj sağlıyor.
# - **Konum:** Galata Kulesi'ne yakınlığı, turistik cazibe merkezlerine kolay erişim sunuyor.
#
# **Bazı ek notlar:** Fiyatların biraz yüksek olduğu belirtiliyor ancak genel olarak yemek kalitesi ve deneyimle orantılı bulunuyor. Glutensiz seçenekler mevcut olması da dikkat çekici bir detay.
#
# F&B Culture, İstanbul'da hem lezzetli yemekler hem de keyifli bir atmosfer arayanlar için ideal bir tercih sunuyor. | İmkanlar: teras | Uygun: romantik | Menü: kebap çeşitleri
# 5. beso_rooftop_restaurant (Puan: 0.8) | Özet: Beso restoranı hakkında yapılan yorumlar genel olarak olumlu yönde. İşte öne çıkan özellikler:
#
# **Manzara:** Restoranın en çok övülen özelliği muhteşem manzarası. Özellikle gün batımında şehrin panoramik görünümü misafirler tarafından sıklıkla vurgulanıyor.
#
# **Hizmet Kalitesi:** Fatma ve Ivy gibi hosteslerin yanı sıra Enes, Anas ve diğer çalışanların güler yüzlü, ilgili ve profesyonel hizmetleri müşteriler tarafından takdir ediliyor. Misafirperverlik ve samimiyet özellikle dikkat çekiyor.
#
# **Lezzetli Yemekler:** Türk mutfağından lezzetli yemekler sunuluyor. Özellikle Adana kebap, biftek makarna, mezeler ve nargile beğeni topluyor. Kokteyller de övgü alıyor.
#
# **Atmosfer:** Şık ama rahat bir atmosferi olan restoran, hem romantik akşam yemekleri hem de arkadaş grupları için ideal bir ortam sunuyor. Canlı müzik ve DJ performansları da eğlenceyi artırıyor.
#
# **Eksiler:** Bazı yorumlarda fiyatların yüksek olduğu belirtiliyor. Ayrıca park yeri bulmanın zorluğu ve İngilizce konuşmayan personel sayısının fazla olması eleştiri konusu oluyor.
#
# Genel olarak Beso, İstanbul'da unutulmaz bir akşam geçirmek isteyenler için manzara, hizmet ve lezzet dengesiyle öne çıkan bir restoran gibi görünüyor. | İmkanlar: canlı müzik | Uygun: romantik | Menü: adana kebap
#
# 🔥 TEST 5: İzmir'de yüksek puanlı pizzacılar
# ✨ Önerilen mekanlar:
# 1. foca_kirke_otel_pizzeria (Puan: 0.88) | Özet: Kirke Pizzeria, Foça'da ince hamurlu ve odun ateşinde pişen lezzetli pizzalarıyla öne çıkan bir mekân olarak dikkat çekiyor. Müşteriler tarafından sıklıkla vurgulanan özellikler arasında;
#
# **Lezzet:** Pizzaların malzeme kalitesi, çıtır hamuru ve dengeli sosları müşterilerin beğenisini kazanıyor. Özellikle Kirke, Odysseus ve Phokaia gibi çeşitler övgü alıyor.
# **Servis:** Çalışanların güler yüzlü ve ilgili tavrı memnuniyet yaratıyor. Personelin önerileri de deneyimleri zenginleştiriyor.
#
# **Atmosfer:** Samimi ve sıcak bir ortam sunuluyor. Taş duvarlar, odun ateşinin kokusu ve genel ambiyans keyifli bir akşam yemeği için ideal bir atmosfer yaratıyor.
#
# **Fiyat-Performans:** Fiyatların makul olduğu ve lezzet kalitesiyle uyumlu olduğu belirtiliyor. İzmir merkezdeki pizzalara kıyasla daha uygun fiyatlı olması da tercih sebebi oluyor.
#
# **Eksiler:** Servis hızı bazen yavaşlayabiliyor, bu durum bazı müşterileri rahatsız ediyor. Ayrıca menünün biraz daha genişletilmesi ve deniz ürünlü veya farklı peynir kombinasyonları eklenmesi öneriliyor.
#
# Genel olarak Kirke Pizzeria, Foça'da pizza keyfi yapmak isteyenler için lezzetli seçenekler sunan bir mekân olarak öne çıkıyor. | Menü: odysseus pizza, phokaia pizza, kirke pizza
# 2. kuzinar_foca (Puan: 0.88) | Özet: **Kuzina**, Foça'da lezzetli yemekler, samimi atmosfer ve güler yüzlü hizmet sunan bir restoran olarak öne çıkıyor.
#
# **Yemek Kalitesi:**
# - Zeytinyağlılar (özellikle kabak çiçeği dolması, kereviz, bakla) ve mezeler sıklıkla övülüyor.
# - Patates pizza, kiremitte köfte, yaprak ciğer gibi ana yemekler de beğeniliyor.
# - Kahvaltı tabağı bol çeşitli ve lezzetli bulunuyor.
#
# **Olumlu Yönler:**
# - **Samimi Atmosfer:** Küçük, şirin ve huzurlu bir mekan olarak tanımlanıyor. Sokakta oturmak da keyifli.
# - **Güler Yüzlü Hizmet:** İşletme sahipleri ve çalışanlar çok ilgili ve samimi bulunuyor.
# - **Lezzetli Yemekler:** Özellikle zeytinyağlılar, mezeler ve bazı ana yemekler öne çıkıyor.
#
# **Olumsuz Yönler:**
# - **Fiyatlar:** Bazı müşteriler fiyatların yüksek olduğunu belirtiyor.
# - **Servis Hızı:** Bazen yemeklerin geç geldiği yorumları var.
# - **Pos Cihazı Sorunu:** Pos cihazının sık sık bozuk olduğu ve nakit ödeme veya IBAN ile işlem yapılması gerektiği söyleniyor.
#
# **Özetle:** Kuzina, Foça'da lezzetli ev yemekleri arayanlar için güzel bir seçenek. Ancak fiyatların yüksekliği ve pos cihazı sorunu dikkate alınması gereken noktalar.
#
# **Tavsiye:**
# - Zeytinyağlı tabağı, kabak çiçeği dolması, patates pizza ve yaprak ciğer denenebilir.
# - Kahvaltı da oldukça başarılı görünüyor.
# - Nakit para bulundurmak faydalı olabilir. | Menü: patates pizza
# 3. lebon_jardin_urla (Puan: 0.88) | Özet: Lebon Jardin, Urla'nın sanat sokağında yer alan ve özellikle atmosferiyle öne çıkan bir mekan olarak değerlendiriliyor. Dekorasyonu, iç dizaynı ve genel ambiyansı misafirler tarafından sıklıkla övülüyor. Canlı müzik performansları ve DJ setleri de mekânın cazibesini artırıyor.
#
# Mekanın en çok vurgulanan özelliği hizmet kalitesi. Çalışanların güler yüzlü, ilgili ve profesyonel olduğu belirtiliyor. Özellikle Ceyhun Bey, Süphan Bey, Yiğit Bey ve Esma Hanım gibi çalışanlar misafirlerden olumlu geri bildirimler alıyor.
#
# Kokteylleri de oldukça beğenilen Lebon Jardin'de bazı yorumlarda yemeklerin lezzetli olduğu vurgulanırken, bazılarında ise fiyat-performans dengesinin iyi olmadığına dair eleştiriler yer alıyor. Hamburger ve pizzalar özellikle övülen ürünler arasında. Kahve konusunda ise karışık görüşler mevcut; bazıları kahvelerin lezzetsiz olduğunu belirtirken, diğerleri beğenilerini ifade ediyor.
#
# Mekanla ilgili en sık dile getirilen olumsuz yorumlar hizmet kalitesindeki tutarsızlık ve rezervasyon politikalarıyla ilgili. Bazı misafirler boş masalara rağmen yer bulamadıklarını veya bekletildiklerini söylüyor. Ayrıca, bazı ürünlerin tazeliğiyle ilgili şikayetler de bulunuyor.
#
# Sonuç olarak Lebon Jardin, Urla'da keyifli bir akşam geçirmek isteyenler için atmosferi ve hizmet kalitesiyle öne çıkan bir mekan. Ancak yemek lezzetleri ve fiyatlar konusunda beklentilerinizi önceden ayarlamanız faydalı olabilir. | İmkanlar: canlı müzik | Menü: pizza
# 4. la_fourmi_restaurant (Puan: 0.88) | Özet: La Fourmi Alsancak, İzmir'in popüler ve nezih restoranlarından biri olarak öne çıkıyor. Müşteriler genel olarak yemeklerin lezzetini, porsiyon büyüklüğünü ve sunumunu övgüyle anlatıyorlar. Özellikle pizzaları, makarnaları, et yemekleri (bonfile, ciğer kebap) ve başlangıç tabağı öneriliyor.
#
# Mekanın atmosferi de sıkça övülüyor; şık dekorasyon, rahat oturma düzeni ve canlı müzik seçenekleriyle romantik akşamlar veya özel günler için ideal bir ortam sunuyor. Çalışanların güler yüzlü ve ilgili hizmetleri de müşteri memnuniyetini artırıyor.
#
# Fiyatlar genel olarak bu kalitede bir restorana göre makul bulunuyor, ancak bazı müşteriler özellikle kokteyllerin fiyatının yüksek olduğunu belirtiyor. Vale hizmeti sunulması da park sorunu yaşayanlar için büyük avantaj sağlıyor.
#
# Ancak bazı olumsuz geri bildirimler de mevcut. Yemeklerin lezzetine rağmen porsiyonların küçük olduğu, servis kalitesinin zaman zaman düştüğü ve gürültülü müzik nedeniyle sohbetin zorlaştığı eleştirileri yapılıyor. Ayrıca bir müşteri kırık tabakla servis edildiğini belirtmiş.
#
# Genel olarak La Fourmi Alsancak, lezzetli yemekler, şık atmosfer ve iyi hizmet sunan bir restoran olarak öne çıkıyor. Ancak bazı küçük eksiklikleri göz önünde bulundurarak rezervasyon yapmadan önce menü ve ambiyans hakkında detaylı bilgi almak faydalı olabilir. | İmkanlar: canlı müzik | Uygun: romantik | Menü: pizza
# 5. dut_restaurant_cafe_bar (Puan: 0.87) | Özet: Dut Kafe, İzmir'in popüler mekanlarından biri olarak öne çıkıyor. Özellikle **konumu ve ambiyansı** müşteriler tarafından sıklıkla övülüyor. Sahil kenarında bulunan kafe, gün batımı manzarasıyla romantik bir atmosfer sunuyor. İki katlı yapısı ve arka bahçesiyle farklı oturma seçenekleri sunarken, loş aydınlatma ve ahşap detaylarla şık bir dekorasyon dikkat çekiyor.
#
# **Yemek ve içecek kalitesi** de mekanın güçlü yönlerinden biri olarak vurgulanıyor. Özellikle **cheesecakeleri**, **pizza**, **köz patlıcanlı yemekler** ve **kokteyller** beğeni topluyor. Kahvaltı seçenekleri de mevcut, ancak bazı müşteriler bekleme süresi ve porsiyon boyutları konusunda eleştirilerde bulunmuşlar.
#
# Fiyatlar genel olarak yüksek bulunuyor ve bu durum sıkça eleştiriliyor. Bazı müşteriler **fahiş fiyatlara** dikkat çekerken, diğerleri menüdeki çeşitlilik ve kaliteyi fiyatla haklı çıkarıyor. Personel güler yüzlü ve ilgili olmakla birlikte, bazı durumlarda hizmet kalitesinde düşüş yaşandığı belirtiliyor.
#
# Mekanın en büyük dezavantajlarından biri **rezervasyon politikası**. Bazı müşteriler rezervasyonsuz gittiklerinde yer bulamadıklarını veya bekletildiklerini ifade ediyorlar. Ayrıca, mekanın bazı bölümlerinin (örneğin arka bahçe) erken saatlerde açılmaması da eleştiri konusu oluyor.
#
# Özetle, Dut Kafe İzmir'de keyifli bir atmosfer ve lezzetli yemekler sunan bir mekan ancak yüksek fiyatlar ve hizmet kalitesindeki dalgalanmalar dikkat edilmesi gereken noktalar arasında yer alıyor. | İmkanlar: bahçe | Uygun: romantik | Menü: pizza
#
# 🔥 TEST 6: İstanbul'da temiz burgerci
# ✨ Önerilen mekanlar:
# 1. the_corner_heybeliada (Puan: 0.88) | Özet: Bu yorumlardan çıkarılabilecek ortak noktalar şunlar:
#
# **Olumlu Yönler:**
#
# - **Lezzetli Yemekler:** Özellikle köfte ekmek, hamburger ve balık ekmek sıklıkla övülmüş. Ev yapımı lezzetleri tercih eden müşteriler için ideal bir seçenek gibi görünüyor.
# - **Güler Yüzlü ve Samimi Hizmet:** Çalışanların sıcakkanlılığı, misafirperverliği ve ilgisi birçok yorumda vurgulanmış. Kaya Amca, Aydın Bey gibi isimler özellikle övgü alıyor.
# - **Uygun Fiyatlar:** Ada şartlarına göre fiyatların makul olduğu belirtiliyor. Öğrenci dostu bir mekan olarak da nitelendiriliyor.
# - **Temiz ve Rahat Ortam:** Mekanın temizliği, huzurlu atmosferi ve güzel manzarası müşteriler tarafından beğenilmiş.
#
# **Eleştiriler:**
#
# - **Hızlı Servis Sorunu:** Birkaç yorumda yemeklerin uzun sürede geldiği belirtiliyor.
# - **Hijyen Eksikliği:** Bazı yorumlarda bardakların temizliği konusunda şikayet var.
# - **Sinek Problemi:** Açık havada hizmet verdikleri için sinek sorunu yaşandığına dair bir yorum mevcut.
#
# **Sonuç Olarak:**
#
# Heybeliada'da lezzetli yemekler, samimi hizmet ve uygun fiyatlar arayanlar için bu mekan iyi bir seçenek gibi görünüyor. Ancak hızlı servis ve hijyen konusunda dikkat edilmesi gereken noktalar var. | Menü: hamburger
# 2. dayi_cafe_restaurant (Puan: 0.86) | Özet: Restoran hakkında yapılan yorumlar genel olarak **karışık** bir tablo çiziyor.
#
# **Olumlu Yönler:**
#
# - Bazı müşteriler yemeklerin lezzetinden, özellikle de lahmacun, pide ve hamburgerden memnun kaldıklarını belirtiyorlar.
# - Çalışanların güler yüzlü ve ilgili olduğu vurgulanıyor, özellikle Zeynep adlı çalışanın müşteri memnuniyetine önem verdiği belirtiliyor.
# - Mekanın temizliği ve ferah atmosferi de olumlu yorumlarda sıkça geçiyor.
#
# **Olumsuz Yönler:**
#
# - **Hizmet kalitesi** genel olarak düşük bulunuyor. Garsonların ilgisi yetersiz, siparişlerin geç geldiği, tabakların uzun süre masada kaldığı ve hesap istemenin bile zaman aldığı eleştiriliyor.
# - Yemeklerin lezzeti konusunda da tutarsızlıklar var: Bazı müşteriler yemekleri beğenirken, bazıları özellikle iskenderin kötü olduğunu, etin kuru veya yanık olduğunu belirtiyor. Ayrıca porsiyonların küçük ve fiyatların yüksek olduğu da sıkça dile getiriliyor.
# - **Hijyen** konusu da eleştiri alan bir nokta: Tuvaletlerin temiz olmadığı, tabaklarda kıl çıktığı gibi şikayetler mevcut.
# - Fiyatlandırma politikası müşterileri rahatsız ediyor: Özellikle maç izlemek için ek ücret alınması ve oturmak için bile kişi başı 100 TL talep edilmesi tepki çekiyor.
#
# **Genel Değerlendirme:**
#
# Restoranın **potansiyeli var**, ancak hizmet kalitesini artırıp tutarlı bir lezzet sunabilmek için bazı iyileştirmeler yapması gerekiyor. Müşteri memnuniyetine daha fazla önem vermeli, hijyen standartlarını yükseltmeli ve fiyat politikasını gözden geçirmelidir.
#
# **Tavsiye:** Bu restoranı tercih edecek olanlar, özellikle hizmet kalitesi ve temizlik konusunda dikkatli olmalıdır. Yemeklerin lezzeti kişiden kişiye değişebileceği için beklentileri düşük tutmak faydalı olabilir. | Menü: hamburger
# 3. cross_fingers_etiler (Puan: 0.86) | Özet: Cross Fingers, Alkent'teki sakin ve nezih atmosferiyle öne çıkan bir mekan olarak tanımlanıyor. Özellikle burgerleri (özellikle Cross Smash) ve çıtır tavuk menüleri sıklıkla övülüyor. Tatlı patates kızartması da lezzetli bulunuyor. Kokteyllerin çeşitliliği ve kalitesi de müşteriler tarafından beğeniliyor.
#
# Mekanın artıları arasında güler yüzlü ve ilgili personel, hızlı servis, temizlik ve çocuk dostu ortam sayılabilir. Açık alan seçeneği de yaz aylarında tercih sebebi oluyor. Ancak bazı müşteriler porsiyonların fiyatına göre küçük olduğunu, patates kızartmasının ekstra ücretli olması ve menü fiyatları arasındaki farkları eleştiriyor. Servis ücreti hesaba eklenmesi de rahatsızlık yaratabiliyor.
#
# Genel olarak Cross Fingers, lezzetli yemekleri ve keyifli atmosferiyle tercih edilen bir mekan olsa da fiyat-performans dengesinin bazı müşteriler tarafından sorgulandığı görülüyor. | Uygun: sakin | Menü: cross smash burger
# 4. da_panela_cafe_restaurant (Puan: 0.86) | Özet: Bu restoran, özellikle lezzetli yemekleri ve kaliteli malzemeleriyle öne çıkıyor. Müşteriler hamburger, pizza, tava yemekleri ve makarnaları övgüyle anlatıyorlar. Ayrıca mekanın temizliği, ferah ambiyansı ve güler yüzlü çalışanları da sıkça vurgulanıyor.
#
# Bazı müşteriler servis hızında gecikme yaşadıklarını belirtiyorlar, ancak genel olarak hizmet kalitesi olumlu karşılanıyor. Birkaç kişi kapalı alanda sigara içilmesine dair şikayetlerde bulunmuşlar. Fiyatların uygun olduğu ve porsiyonların bol olduğu da sıkça dile getirilmiş.
#
# Sonuç olarak, bu restoran lezzetli yemekleri, kaliteli hizmeti ve hoş ambiyansı ile bölgede tercih edilen bir mekan olarak öne çıkıyor. | Menü: hamburger
# 5. mienyu (Puan: 0.85) | Özet: Mienyu restoranı, özellikle lezzetli hamburgerleri ve çeşitli dünya mutfağı seçenekleriyle öne çıkıyor. Müşteriler genellikle yemeklerin kalitesini ve porsiyon büyüklüğünü övgüyle anlatıyorlar. Ancak, bazı müşteriler fiyatların yüksek olduğunu ve hizmet bedelinin eklenmesini eleştiriyor. Ayrıca, servis hızında zaman zaman aksaklıklar yaşandığına dair şikayetler mevcut. Mekanın atmosferi genel olarak beğeniliyor; temizlik ve hijyen de olumlu yorumlarda sıkça vurgulanıyor. Lavabolarda kullanılan tek kullanımlık el havlularının yerine kağıt havlu tercih edilmesi gibi küçük detaylar ise bazı müşteriler tarafından eleştiriliyor. Mienyu, Yeşilköy bölgesinde popüler bir seçenek olarak öne çıkıyor ancak fiyat politikası ve hizmet bedeli konusunda daha şeffaf olunması gerektiği belirtiliyor.
#
# Özetle: Lezzetli yemekler, geniş menü çeşitliliği ve temiz ortamı ile dikkat çeken Mienyu, yüksek fiyatlar ve hizmet bedelinin eklenmesi gibi konularda eleştiriliyor. | Menü: lezzetli hamburger

# %%
def format_chatbot_response_simple(results):
    if not results:
        return "⚠ Hiç uygun mekan bulunamadı."

    cevap = ["✨ Önerilen mekanlar:"]

    # Restoranları numaralandırarak listele
    for i, r in enumerate(results, 1):
        # Restoran adı (Bilinmeyen restoran adını döndürmek yerine sadece adı alıyoruz)
        line = f"{i}. {r.get('restoran', 'Bilinmeyen Restoran')}"

        # Satıra eklenen restoran bilgisini cevap listesine ekliyoruz
        cevap.append(line)

    return "\n".join(cevap)

print("🎯 CHATBOT TABANLI ÇOKLU RELATION TESTLERİ")
print("=" * 60)

# Neo4j bağlantısı var mı kontrol edelim
if not kg:
    print("❌ Neo4j bağlantısı yok!")
else:
    print("✅ Neo4j bağlantısı aktif")

# Test 1: Ankara'da kebap menüsü ve çocuk parkı olan restoranlar
print("\n🔥 TEST 1: Ankara'da kebap menüsü ve çocuk parkı olan restoranlar")
criteria1 = {
    "city": "ankara",
    "menu": "kebap",
    "amenities": ["çocuk parkı"],
    "limit": 3
}
results1 = chatbot_query_restaurants(kg, criteria1, limit=5) if kg else []
if results1:
    print(format_chatbot_response_simple(results1))  # Sonuçları formatla ve sadece isimleri göster
else:
    print("❌ Bu kriterlere uygun restoran bulunamadı.")
    print("💡 Daha az kriter ile tekrar deneyin.")

# Test 2: İstanbul'da romantik ve yüksek puanlı kebap restoranları
print("\n🔥 TEST 2: İstanbul'da romantik ve yüksek puanlı kebap restoranları")
criteria2 = {
    "city": "istanbul",
    "menu": "kebap",
    "occasion": "romantik",
    "min_score": 0.8,
    "limit": 3
}
results2 = chatbot_query_restaurants(kg, criteria2, limit=5) if kg else []
if results2:
    print(format_chatbot_response_simple(results2))  # Sonuçları formatla ve sadece isimleri göster
else:
    print("❌ İstanbul'da romantik ve yüksek puanlı kebap restoranı bulunamadı.")
    print("💡 Daha az kriter ile tekrar deneyin.")

# Test 3: İzmir Konak'ta pizza menüsü olan restoranlar
print("\n🔥 TEST 3: İzmir Konak'ta pizza menüsü olan restoranlar")
criteria3 = {
    "city": "izmir",
    "district": "konak",
    "menu": "pizza",
    "limit": 3
}
results3 = chatbot_query_restaurants(kg, criteria3, limit=5) if kg else []
if results3:
    print(format_chatbot_response_simple(results3))  # Sonuçları formatla ve sadece isimleri göster
else:
    print("❌ İzmir Konak'ta pizza menüsü olan restoran bulunamadı.")
    print("💡 Daha az kriter ile tekrar deneyin.")
# Out:
# 🎯 CHATBOT TABANLI ÇOKLU RELATION TESTLERİ
# ============================================================
# ✅ Neo4j bağlantısı aktif
#
# 🔥 TEST 1: Ankara'da kebap menüsü ve çocuk parkı olan restoranlar
# ❌ Bu kriterlere uygun restoran bulunamadı.
# 💡 Daha az kriter ile tekrar deneyin.
#
# 🔥 TEST 2: İstanbul'da romantik ve yüksek puanlı kebap restoranları
# ✨ Önerilen mekanlar:
# 1. papuli_restaurant
# 2. arca_restaurant_grill
# 3. roof_mezze_360_restaurant
# 4. fb_culture
# 5. beso_rooftop_restaurant
#
# 🔥 TEST 3: İzmir Konak'ta pizza menüsü olan restoranlar
# ✨ Önerilen mekanlar:
# 1. la_fourmi_restaurant
# 2. favino_alsancak

# %% [markdown]
# -----------------------------------------

# %%
import re

def parse_user_input(user_input):
    """
    Kullanıcının serbest metnini, restoran arama kriterlerine ayıran fonksiyon.
    """
    user_input = user_input.lower()  # Cümleyi küçük harfe çeviriyoruz

    # Başlangıçta boş değerler
    city = None
    district = None
    menu = None
    occasion = None
    amenities = []
    min_score = None

    # Şehir için anahtar kelimeler
    cities = ["ankara", "istanbul", "izmir"]
    for city_name in cities:
        if city_name in user_input:
            city = city_name
            break

    # İlçe için anahtar kelimeler
    districts = ["kadıköy", "beşiktaş", "şişli", "fatih", "üsküdar", "bakırköy", "beyoğlu", "maltepe", "kartal", "ataşehir", "bağcılar", "zeytinburnu", "avcılar",
                "çankaya", "keçiören", "mamak", "etimesgut", "sincan", "yenimahalle", "altındağ", "çubuk", "polatlı", "gölbaşı", "pursaklar", "bala",
                "konak", "karşıyaka", "bornova", "buca", "çiğli", "alsancak", "gaziemir", "bayraklı", "narlıdere", "menemen", "foça", "urla"]
    for district_name in districts:
        if district_name in user_input:
            district = district_name
            break

    # Menü öğeleri
    menu_items = ["kebap", "pizza", "burger", "mantı", "adana dürüm", "kahvaltı", "tatlı", "çorba", "meze", "salata", "baklava", "künefe", "sushi", "ramen", "pizza", "hamburger", "burger", "biftek", "falafel", "humus", "shawarma", "taco", "burrito", "curry", "penne", "spaghetti", "risotto", "gnocchi", "türk mutfağı", "geleneksel türk mutfağı", "kahvaltı", "tatlı"]
    for item in menu_items:
        if item in user_input:
            menu = item
            break

    # Özel günler
    occasions = ["romantik", "aile", "iş yemeği", "doğum günü", "tatil", "sevgililer günü"]
    for occasion_type in occasions:
        if occasion_type in user_input:
            occasion = occasion_type
            break

    # İmkanlar
    amenity_keywords = ["bahçe", "çocuk parkı", "otopark", "wi-fi", "canlı müzik", "deniz manzarası", "teras", "açık alan", "açık hava"]
    for amenity in amenity_keywords:
        if amenity in user_input:
            amenities.append(amenity)

    # Min score (puan) için regex
    score_match = re.search(r"\b(\d\.\d)\b", user_input)
    if score_match:
        min_score = float(score_match.group(1))

    # Kriterleri dictionary'ye yerleştiriyoruz
    criteria = {
        "city": city,
        "district": district,
        "menu": menu,
        "occasion": occasion,
        "amenities": amenities,
        "min_score": min_score,
        "limit": 5
    }

    return criteria

def chatbot_interface(kg, data):
    print("🎯 Merhaba! Restoran arama chatbot'uma hoş geldiniz.")
    print("=" * 60)

    while True:
        print("\nLütfen restoran arama kriterlerinizi tek bir cümle olarak girin:")

        # Kullanıcıdan serbest metin alın
        user_input = input("Restoran arama cümlenizi girin (örneğin: 'İstanbul'da romantik kebapçılar' veya 'Ankara'da kebap yiyebileceğim yerler'): ")

        # Cümleyi parse et
        criteria = parse_user_input(user_input)

        # Restoranları arıyoruz
        results = chatbot_query_restaurants(kg, criteria, limit=5)

        if results:
            # Sonuçları formatla
            formatted_response = format_chatbot_response(results, data)
            print("\n🎯 Restoranlar:")
            print(formatted_response)
        else:
            print("❌ Bu kriterlere uygun restoran bulunamadı.")

        # Yeni bir arama yapmak isteyip istemediğini sor
        again = input("\nYeni bir arama yapmak ister misiniz? (Evet/Hayır): ").strip().lower()
        if again != "evet":
            print("👋 Teşekkürler! İyi günler dilerim.")
            break

def chatbot_query_restaurants(kg, criteria, limit=5):
    if kg is None:
        return [{"error": "Neo4j bağlantısı yok"}]

    with kg.driver.session() as session:
        match_clauses = ["(r:Restaurant)"]
        conditions = []
        params = {"limit": limit}

        # Şehir
        if "city" in criteria and criteria["city"]:
            match_clauses.append("(r)-[:LOCATED_IN]->(city:Location)")
            conditions.append("toLower(city.name) = $city")
            params["city"] = criteria["city"]

        # İlçe
        if "district" in criteria and criteria["district"]:
            match_clauses.append("(r)-[:LOCATED_IN]->(district:Location)")
            conditions.append("toLower(district.name) = $district")
            params["district"] = criteria["district"]

        # Menü
        if "menu" in criteria and criteria["menu"]:
            match_clauses.append("(r)-[:SERVES]->(m:MenuItem)")
            conditions.append("toLower(m.name) CONTAINS $menu")
            params["menu"] = criteria["menu"]

        # Özel gün
        if "occasion" in criteria and criteria["occasion"]:
            match_clauses.append("(r)-[:SUITS_OCCASION]->(o:Occasion)")
            conditions.append("toLower(o.name) = $occasion")
            params["occasion"] = criteria["occasion"]

        # İmkanlar
        if "amenities" in criteria and criteria["amenities"]:
            for i, amenity in enumerate(criteria["amenities"]):
                match_clauses.append(f"(r)-[:HAS_AMENITY]->(a{i}:Amenity)")
                conditions.append(f"toLower(a{i}.name) CONTAINS $amenity{i}")
                params[f"amenity{i}"] = amenity

        # Min puan
        if "min_score" in criteria and criteria["min_score"]:
            match_clauses.append("(r)-[rating:RATED_FOR]->(asp:Aspect)")
            conditions.append("rating.score >= $min_score")
            params["min_score"] = criteria["min_score"]

        match_clause = "MATCH " + ", ".join(match_clauses)
        where_clause = "WHERE " + " AND ".join(conditions) if conditions else ""

        query = f"""
        {match_clause}
        {where_clause}
        OPTIONAL MATCH (r)-[rt:RATED_FOR]->(asp:Aspect)
        OPTIONAL MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
        OPTIONAL MATCH (r)-[:SERVES]->(m:MenuItem)
        OPTIONAL MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
        WHERE rt.sentiment = 'positive'
        WITH r,
             avg(rt.score) as avg_score,
             collect(DISTINCT asp.name) as aspects,
             collect(DISTINCT am.name) as amenities,
             collect(DISTINCT m.name) as menu_items,
             collect(DISTINCT o.name) as occasions
        RETURN r.name as restoran,
               round(avg_score,2) as ortalama_puan,
               aspects, amenities, menu_items, occasions
        ORDER BY ortalama_puan DESC
        LIMIT $limit
        """

        result = session.run(query, params)
        return [dict(record) for record in result]

kg = Neo4jKnowledgeGraph(uri="bolt://localhost:7687", user="neo4j", password="12345678")
chatbot_interface(kg, data)
# Out:
# 🎯 Merhaba! Restoran arama chatbot'uma hoş geldiniz.
# ============================================================
#
# Lütfen restoran arama kriterlerinizi tek bir cümle olarak girin:
#
# 🎯 Restoranlar:
# ✨ Önerilen mekanlar:
# 1. vento_italiano_ristorante (Puan: None) | Özet: Hata: Error code: 400 - {'error': 'Trying to keep the first 8813 tokens when context the overflows. However, the model is loaded with context length of only 8192 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input'}
# 2. delicatessen_etiler (Puan: None) | Özet: Hata: Error code: 400 - {'error': 'Trying to keep the first 8338 tokens when context the overflows. However, the model is loaded with context length of only 8192 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input'}
# 3. carsi_ici_merkez_lokantasi (Puan: None) | Özet: Restoran, müşteriler tarafından "harika" olarak nitelendiriliyor ve bu olumlu geri bildirimle öne çıkıyor.
# 4. aykoc_restoran (Puan: None) | Özet: Merhaba! 😊
#
# Geçen gün restoranımıza gelen misafirlerimizden biri olduğunuzu düşünüyorum. Yanlışlıkla bir kişinin hesabını ödemeyi unuttuğunuzu belirtmişsiniz. Telefon numaranızı bulamadığınız için iletişime geçmek istediğinizi söylemişsiniz.
#
# Restoranımızın telefon numarası: **0532 123 4567**'dir. Lütfen bu numarayı arayarak bizimle iletişime geçebilirsiniz. Borcunuzu ödemeniz için size yardımcı olacağız. 😊
#
# İyi günler dilerim!
# [Restoran Adınız] Ekibi
# 5. studyo_pizza (Puan: None) | Özet: Hata: Error code: 400 - {'error': 'Trying to keep the first 8317 tokens when context the overflows. However, the model is loaded with context length of only 8192 tokens, which is not enough. Try to load the model with a larger context length, or provide a shorter input'}
#
# Lütfen restoran arama kriterlerinizi tek bir cümle olarak girin:
#
# 🎯 Restoranlar:
# ✨ Önerilen mekanlar:
# 1. naif_restaurant (Puan: 0.88) | Özet: Restoran hakkında yapılan yorumlar genel olarak olumlu yönde. Özellikle **mezelerin lezzeti ve hızlı servis** sıklıkla vurgulanıyor. Ayrıca **canlı müzik performansı**, **huzurlu atmosfer** ve **profesyonel çalışanlar** da beğenilen özellikler arasında yer alıyor.
#
# Ancak bazı yorumlarda **havalandırma sorunu, yüksek fiyatlar ve pahalı hesaplar** gibi olumsuz noktalara değiniliyor. Bazı müşteriler mekanın **basık ve havasız** olduğunu düşünüyor. Ayrıca **fiyat-performans dengesi** konusunda eleştiriler var; özellikle içki fiyatları ve mezelerin maliyeti yüksek bulunuyor.
#
# Özetle, restoran lezzetli mezeleri, canlı müziği ve huzurlu atmosferiyle beğeniliyor ancak fiyatlar ve havalandırma sorunu bazı müşterileri rahatsız ediyor. | İmkanlar: canlı müzik | Menü: meze lezzeti
# 2. neff_cafe_nargile (Puan: 0.88) | Özet: Restoran hakkında yapılan yorumlar genel olarak **çelişkili** bir tablo çiziyor.
#
# **Olumlu yönler:**
#
# - **Güler yüzlü personel**: Birçok müşteri, çalışanların sıcak ve ilgili olduğunu vurguluyor. Özellikle Aslı Hanım, Büşra Hanım ve Okan Bey gibi isimler sıklıkla övülüyor.
# - **Lezzetli kahvaltı**: Serpme kahvaltının çeşitliliği ve lezzeti beğenilmiş.
# - **Aile dostu ortam**: Sakin ve huzurlu bir atmosfer sunması aileler için tercih sebebi oluyor.
# - **Canlı müzik**: Canlı müzik performansları eğlenceli bulunmuş.
# - **Uygun fiyatlar**: Fiyatların Keçiören piyasasına göre makul olduğu belirtiliyor.
#
# **Olumsuz yönler:**
#
# - **Hizmet kalitesi**: Bazı müşteriler siparişlerin geç geldiğini, garsonların ilgisiz davrandığını ve genel olarak hizmetin yetersiz olduğunu ifade ediyor.
# - **Hijyen sorunları**: Tuvaletlerin temizliği sıklıkla eleştiriliyor. Ayrıca mutfak hijyeni konusunda da şüpheler dile getiriliyor (örneğin kıl çıkması).
# - **Kaliteli malzeme kullanımı**: Kahve, çay ve nargile gibi ürünlerde kullanılan malzemelerin kalitesiz olduğu yorumları mevcut.
# - **Fiyat farkı**: Menüde belirtilen fiyatlarla gelen hesap arasında fark olması müşterileri rahatsız ediyor.
# - **Ortamın düzensizliği**: Bazı müşteriler mekanın temizliğinden ve genel düzeninden memnun kalmamış.
#
# **Genel olarak:** Restoran, potansiyelini tam anlamıyla gerçekleştirememiş gibi görünüyor. Güler yüzlü personel ve lezzetli kahvaltı gibi olumlu yönleri bulunsa da hijyen sorunları, hizmet kalitesinin düşüklüğü ve fiyat politikaları nedeniyle müşteri memnuniyeti konusunda ciddi sıkıntılar yaşıyor. İşletme yönetiminin bu sorunlara çözüm bulması halinde daha başarılı olabilir. | İmkanlar: canlı müzik | Uygun: aile, sakin, eğlenceli
# 3. amarillo (Puan: 0.85) | Özet: Amarillo, Ankara'da canlı müzik eşliğinde keyifli vakit geçirebileceğiniz, nezih ve kaliteli bir mekan olarak öne çıkıyor. Müşteriler genellikle ortamın sıcak atmosferini, lezzetli yemeklerini (özellikle burgerler, taco'lar ve antrikot) ve geniş içecek menüsünü övüyor. Canlı müzik performansları da özellikle hafta sonları yoğun ilgi görüyor.
#
# Mekanın bazı dezavantajları arasında küçük masalar, kalabalık ortamda sohbet etmenin zorluğu, bazen yavaş servis ve yüksek fiyatlar sayılabilir. Ayrıca, personel davranışlarıyla ilgili olumsuz yorumlar da mevcut. Ancak genel olarak Amarillo, Ankara'nın popüler mekanlarından biri olarak öne çıkıyor ve özellikle arkadaşlarla buluşmak veya keyifli bir akşam geçirmek için tercih ediliyor.
#
# Özetle: Lezzetli yemekler, canlı müzik ve nezih atmosfer arayanlar için ideal bir seçenek. | İmkanlar: canlı müzik | Menü: taco, burger, taco lar
# 4. badem_restaurant (Puan: 0.85) | Özet: Bu yorumlardan anlaşılan, **Ankara'da yer alan bu restoran**, nezih bir ortamı, lezzetli mezeleri ve canlı müziği ile öne çıkıyor. Müşteriler özellikle **samimi atmosferi**, **güler yüzlü hizmet** ve **kaliteli yemekleri** övgüyle anlatıyorlar.
#
# Restoranın en dikkat çeken özelliklerinden biri de **seçkin müşteri kitlesi**. Bu durum, mekanın sakin ve keyifli bir ortam sunduğunu gösteriyor. Ayrıca, **piyano eşliğinde canlı müzik**, akşamları ziyaretçilere hoş bir atmosfer yaratıyor.
#
# Ancak bazı yorumlarda **sigara içimi** sorunu dile getiriliyor. Mekanın sigara yasağına uymaması ve dumanlı ortamı, bazı müşteriler için olumsuz bir deneyim oluşturuyor. Bu durumun restoranın genel puanını düşürdüğünü söyleyebiliriz.
#
# Sonuç olarak, **lezzetli yemekler**, **nezih atmosfer** ve **canlı müzik** arayanlar için bu restoran iyi bir seçenek olabilir. Ancak sigara içmeyenler veya dumanlı ortamlardan rahatsız olanlar dikkatli olmalıdır. | İmkanlar: canlı müzik | Uygun: sakin
# 5. alt_ust_meyhane (Puan: 0.85) | Özet: Alt Üst Meyhane, Ankara'nın popüler meyhane kültürüne renk katan bir mekan olarak öne çıkıyor. Müşteriler tarafından en çok vurgulanan özellikler arasında **lezzetli ve taze mezeler** geliyor. Özellikle pazı sarma, atom, kız kıza, kısır ve sıcak humus gibi seçenekler sıklıkla övülüyor.
#
# Mekanın samimi ve sıcak atmosferi de beğeni topluyor. Canlı müzik performansları eğlenceyi artırırken, çalışanların güler yüzlü ve ilgili hizmeti müşterileri memnun ediyor. **Duygu Şef'in özenle hazırladığı yemekler** ve işletme sahibi Levent Bey'in misafirperverliği de sıkça övülen unsurlar arasında yer alıyor.
#
# Fiyat-performans dengesinin iyi olduğu belirtiliyor, ancak bazı müşteriler porsiyonların küçük veya fiyatların yüksek olduğunu ifade ediyor. Mekanın **havasız ve kalabalık** olması da eleştirilen noktalardan biri.
#
# Genel olarak Alt Üst Meyhane, lezzetli mezeleri, samimi atmosferi ve canlı müziğiyle Ankara'da rakı ve meze keyfi yapmak isteyenler için tercih edilen bir mekan olarak öne çıkıyor. | İmkanlar: canlı müzik | Menü: sıcak humus
#
# Lütfen restoran arama kriterlerinizi tek bir cümle olarak girin:
#
# 🎯 Restoranlar:
# ✨ Önerilen mekanlar:
# 1. aralik (Puan: 0.86) | Özet: Aralık restoranı hakkında yapılan yorumlar genel olarak olumlu olsa da bazı eleştiriler de mevcut.
#
# **Olumlu Yönler:**
#
# * **Lezzet:** Yemeklerin lezzeti sıklıkla övülüyor, özellikle yaprak ciğer, dana yanak, gnocchi ve kokteyller öne çıkıyor.
# * **Ambiyans:** Romantik, sıcak ve samimi bir atmosfer sunması birçok müşteriyi cezbediyor.
# * **Çalışanlar:** Çoğunlukla güler yüzlü, ilgili ve profesyonel hizmet aldıkları belirtiliyor.
#
# **Eleştiriler:**
#
# * **Fiyat-Performans:** Bazı yorumlarda yemeklerin fiyatının yüksek olduğu ve porsiyonların küçük olduğu vurgulanıyor.
# * **Servis Kalitesi:** Rezervasyon sorunları, sipariş hataları ve bazı çalışanların kaba davranışları eleştiriliyor.
# * **Menü Çeşitliliği:** Vegan seçeneklerinin sınırlı olması ve menünün yeterince çeşitli olmaması bazı müşterileri rahatsız ediyor.
#
# **Genel Değerlendirme:**
#
# Aralık, lezzetli yemekleri ve hoş ambiyansı ile öne çıkan bir mekan. Ancak fiyatlar yüksek ve servis kalitesi bazen düşüş gösterebiliyor. Vegan seçeneklerinin daha fazla çeşitlendirilmesi de olumlu bir adım olabilir.
#
# Mekanı denemek isteyenler, özellikle kokteyller ve ana yemeklerin lezzetine güvenebilirler. Ancak porsiyonların küçük olduğunu ve fiyatları göz önünde bulundurmaları faydalı olacaktır. Ayrıca rezervasyon yaparken dikkatli olmak ve servis konusunda esnek olmak da iyi bir fikir olabilir. | Uygun: romantik | Menü: gnocchi
# 2. 700_gram (Puan: 0.86) | Özet: Bu yorumlardan genel olarak şu özellikler öne çıkıyor:
#
# **Olumlu Yönler:**
#
# * **Lezzet:** Birçok yorumda yemeklerin lezzeti özellikle vurgulanmış. Ekşi mayalı ekmek, kahvaltılık seçenekler, kömür biber çorbası gibi ürünler sıklıkla övülmüş.
# * **Atmosfer:** Mekanın sıcak, samimi ve huzurlu bir ambiyansı olduğu belirtiliyor. Özellikle tarihli mekanın dizaynı ve müzik seçkisi beğenilmiş.
# * **Kahve Kalitesi:** Kahvelerin lezzetli olduğu ve çeşitli süt seçenekleri sunulduğu vurgulanmış. Ancak bazı yorumlarda kahve fiyatlarının yüksek olduğu eleştirisi de yer alıyor.
# * **Ekmek Ürünleri:** Ekşi mayalı ekmeklerin kalitesi sıklıkla övülmüş, hatta evde tüketim için satın alınan bir ürün olarak da tercih edildiği belirtiliyor.
#
# **Eleştirilen Yönler:**
#
# * **Fiyatlar:** Birçok yorumda fiyatların yüksek olduğu ve porsiyonların küçük olduğu eleştirisi var. Özellikle ek ücret talep edilen süt seçenekleri (örneğin badem sütü) bu konuda tepki çekmiş.
# * **Servis Kalitesi:** Bazı yorumlarda servis personelinin ilgisiz, yavaş veya kaba davrandığı belirtiliyor. Siparişlerin gecikmesi ve bazı temel ihtiyaçların (tuz, karabiber gibi) unutulması da eleştirilen noktalar arasında.
# * **Porsiyon Boyutları:** Özellikle kahvaltı menüsünde porsiyonların küçük olduğu ve fiyatın bu boyuta göre yüksek olduğu düşünülüyor.
# * **Kalite Dengesizliği:** Bazı yorumlarda yemeklerin kalitesinin zamanla düştüğü veya tutarsız olduğu belirtiliyor (örneğin, bir gün lezzetli olan bir ürünün başka bir gün bayat olması).
#
# **Genel Değerlendirme:**
#
# Mekanın lezzetli yemekleri ve hoş atmosferi dikkat çekiyor ancak yüksek fiyatlar, servis kalitesindeki dalgalanmalar ve porsiyon boyutları müşterileri memnun etmiyor. Fiyat-performans dengesi konusunda iyileştirmeler yapılması gerektiği vurgulanıyor.
# 3. todori_fenerbahce (Puan: 0.86) | Özet: Todori, şehrin içinde bir kaçamak sunan tarihi bir mekan olarak öne çıkıyor. Bahçesi yaz aylarında özellikle keyifli ve ferah bir atmosfer yaratırken, kışın kapalı alanları da sıcak ve samimi bir ortam sağlıyor.
#
# Yemekler konusunda genel olarak olumlu geri bildirimler alınıyor. Mezeler (özellikle kabak kızartma, yaprak ciğer ve girit ezmesi) ve balık çeşitleri sıklıkla övülüyor. Ayrıca kahvaltı seçeneklerinin de lezzetli olduğu belirtiliyor.
#
# Personel güler yüzlü ve ilgili olarak nitelendiriliyor. Özcan Bey gibi çalışanlar özellikle misafirperverlikleriyle dikkat çekiyor. Ancak, bazı müşteriler servis hızının yavaş olduğunu veya hesaba ekstralar eklendiğini iddia ediyor.
#
# Fiyatlar genel olarak makul bulunuyor ancak bazı müşteriler yüksek fiyatların lezzet ve kaliteye değmediğini düşünüyor. Ayrıca rezervasyon yapmanın özellikle kalabalık gruplar için önemli olduğu vurgulanıyor.
#
# Sonuç olarak Todori, tarihi atmosferi, lezzetli yemekleri ve güler yüzlü personeliyle İstanbul'da keyifli bir akşam yemeği veya kahvaltı deneyimi sunan bir mekan olarak öne çıkıyor. Ancak servis hızı ve fiyatlar konusunda dikkat edilmesi gereken noktalar bulunuyor. | İmkanlar: bahçe | Menü: balık
# 4. antebi_restaurant_ciftehavuzlar (Puan: 0.86) | Özet: Antebi restoranı hakkındaki yorumlar genel olarak olumlu ve lezzet odaklı.
#
# **En sık vurgulanan olumlu noktalar:**
#
# * **Lahmacun:** Çoğu müşteri lahmacunun çıtır, bol etli ve lezzetli olduğunu belirtiyor. Hatta bazıları İstanbul'da yedikleri en iyi lahmacun olarak nitelendiriyor.
# * **Mezeler:** Humus, muhammara, acılı yoğurt gibi mezelerin de oldukça beğenildiği görülüyor. Özellikle humus ve muhamaranın lezzetli olduğu sıklıkla vurgulanıyor.
# * **Et yemekleri:** Kuzu şiş, ciğer kavurma, kıyma kebabı gibi et yemeklerinin de genel olarak başarılı olduğu yorumlanıyor. Ancak bazı müşteriler kuzu şişin tadının farklı olduğunu ve beğenmediklerini belirtmişler.
# * **Servis kalitesi:** Çoğu müşteri garsonların güleryüzlü ve yardımcı olduklarını söylüyor. Ancak yoğun saatlerde servis hızında düşüş yaşandığına dair eleştiriler de mevcut.
#
# **Eleştirilen noktalar ise şunlar:**
#
# * **Fiyatlar:** Birçok müşteri fiyatların yüksek olduğunu düşünüyor, özellikle porsiyon boyutları göz önüne alındığında.
# * **Kuver ücreti:** 230 TL'ye kadar çıkan kuver ücretleri bazı müşterileri rahatsız ediyor. Özellikle su ve pide dışında hiçbir ikram yapılmadığına dair şikayetler var.
# * **Porsiyon boyutları:** Bazı yemeklerin porsiyonlarının küçük olduğu eleştiriliyor. Örneğin, içli köfte ve salataların miktarının yetersiz bulunduğu yorumlanıyor.
# * **Mekan ambiyansı:** Sigara dumanı ve ızgara kokusunun yoğun olması bazı müşterileri rahatsız ediyor.
#
# **Sonuç olarak:** Antebi restoranı lezzetli yemekleri ve güler yüzlü servisiyle öne çıkıyor, ancak yüksek fiyatlar ve kuver ücretleri gibi eksiklikleri de mevcut. Lahmacun ve mezeleri deneyimlemek isteyenler için iyi bir seçenek olabilir, ancak et yemeklerinin porsiyon boyutları ve fiyatları göz önünde bulundurulmalıdır.
#
# **Öneri:** Restoranı ziyaret etmek isteyenlerin rezervasyon yaptırıp yoğun saatlerden kaçınmaları faydalı olacaktır. Ayrıca lahmacun ve mezelere odaklanarak daha ekonomik bir deneyim yaşayabilirler. | Menü: lahmacun, humus
# 5. muutto (Puan: 0.85) | Özet: Muutto restoranı, özellikle lezzetli mezeleriyle öne çıkıyor. Müşteriler, Nazuktan, fırın kabak, tabbule, hardallı levrek ve mantarlı humus gibi mezelerin benzersiz tatlarını ve sunumunu övgüyle anlatıyorlar. Ayrıca dana kaburga dürüm, kuzu mutancana dürüm ve kokoreçli burger gibi ana yemekler de büyük beğeni topluyor.
#
# Restoranın samimi ve güler yüzlü personeli de müşteri memnuniyetini artıran önemli bir faktör olarak vurgulanıyor. Fahri Bey gibi çalışanlar, özellikle ilgi ve alakalarıyla dikkat çekiyorlar. Müşteriler ayrıca mekanın şirin ve sıcak atmosferine de değiniyor.
#
# Bazı müşteriler alkol satışının olmaması ve servis ücretinin alınması gibi küçük eksiklikleri dile getirmiş olsa da genel olarak Muutto, lezzetli yemekleri, samimi ortamı ve kaliteli hizmetiyle İstanbul'da öne çıkan bir restoran olarak tanımlanıyor. | Menü: mantarlı humus, kuzu mutancana dürüm, dana kaburga dürüm
# 👋 Teşekkürler! İyi günler dilerim.

# %% [markdown]
# -------------------------------

# %% [markdown]
# # For Rubric Test

# %%
import pandas as pd

def run_queries_and_store_results(kg):
    # Sorguları tanımlıyoruz
    queries = [
        {
            "name": "Ankara'daki mekanlar",
            "query": """
            MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
            WHERE toLower(l.name) = 'ankara'
            RETURN r.name as restoran, l.name as lokasyon
            LIMIT 10
            """
        },

        {
            "name": "Olumlu tat puanı alan restoranlar",
            "query": """
            MATCH (r:Restaurant)-[rating:RATED_FOR]->(a:Aspect)
            WHERE rating.dimension = 'TASTE' AND rating.sentiment = 'positive'
            RETURN r.name as restoran, a.name as aspekt, rating.score as puan
            ORDER BY rating.score DESC
            LIMIT 10
            """
        },

        {
            "name": "Restoranların imkanları",
            "query": """
            MATCH (r:Restaurant)-[:HAS_AMENITY]->(am:Amenity)
            RETURN r.name as restoran, collect(am.name) as imkanlar
            LIMIT 10
            """
        },

        {
            "name": "İstanbul'da romantik ve yüksek tat puanı olan restoranlar",
            "query": """
            MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
            MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
            MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
            WHERE toLower(l.name) = 'istanbul'
              AND rating.dimension = 'TASTE'
              AND rating.sentiment = 'positive'
              AND toLower(o.name) = 'romantik'
            RETURN r.name as restoran, avg(rating.score) as ortalama_puan
            ORDER BY ortalama_puan DESC
            LIMIT 10
            """
        },
                {
            "name": "Ankara'da bahçeli kebapçılar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(l.name) CONTAINS 'ankara'
                AND toLower(am.name) CONTAINS 'bahçe'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Ankara'da temiz kebapçılar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'ankara'
                AND rating.dimension = 'CLEANLINESS'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Ankara'da hızlı servisli dönerci",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'ankara'
                AND rating.dimension = 'SERVICE'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Ankara'da otoparklı restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(l.name) CONTAINS 'ankara'
                AND toLower(am.name) CONTAINS 'otopark'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Ankara'da çocuk oyun alanlı mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(l.name) CONTAINS 'ankara'
                AND toLower(am.name) CONTAINS 'çocuk'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Ankara'da açık mutfaklı kafeler",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(l.name) CONTAINS 'ankara'
                AND toLower(am.name) CONTAINS 'açık mutfak'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İzmir'de deniz manzaralı balıkçılar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(l.name) CONTAINS 'izmir'
                AND toLower(am.name) CONTAINS 'manzara'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İzmir'de sessiz balıkçılar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'izmir'
                AND rating.dimension = 'AMBIANCE'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İzmir'de canlı müzikli meyhane",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(l.name) CONTAINS 'izmir'
                AND toLower(am.name) CONTAINS 'müzik'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İzmir'de bahçeli kebapçılar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(l.name) CONTAINS 'izmir'
                AND toLower(am.name) CONTAINS 'bahçe'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İzmir'de açık alanlı pizzacılar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(l.name) CONTAINS 'izmir'
                AND toLower(am.name) CONTAINS 'açık alan'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İzmir'de aile salonu olan lokantalar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(l.name) CONTAINS 'izmir'
                AND toLower(am.name) CONTAINS 'aile'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İstanbul'da deniz manzaralı kahvaltıcılar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(l.name) CONTAINS 'istanbul'
                AND toLower(am.name) CONTAINS 'manzara'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İstanbul'da sessiz restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'istanbul'
                AND rating.dimension = 'AMBIANCE'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İstanbul'da otoparklı kebapçılar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(l.name) CONTAINS 'istanbul'
                AND toLower(am.name) CONTAINS 'otopark'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İstanbul'da hızlı servisli pizzacılar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'istanbul'
                AND rating.dimension = 'SERVICE'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İstanbul'da balık menüsü geniş restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'istanbul'
                AND rating.dimension = 'FOOD_VARIETY'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İstanbul'da sigarasız kapalı alan restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(l.name) CONTAINS 'istanbul'
                AND toLower(am.name) CONTAINS 'sigarasız'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Ankara'da Adana kebap yapan restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'ankara'
                AND rating.dimension = 'FOOD_VARIETY'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Ankara'da mantı yapan mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'ankara'
                AND rating.dimension = 'FOOD_VARIETY'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },

        # 21-40: Menu/Cuisine focused queries
        {
            "name": "İzmir'de ince hamur pizzacılar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'izmir'
                AND rating.dimension = 'TASTE'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İzmir'de tatlı menüsü geniş kafeler",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'izmir'
                AND rating.dimension = 'FOOD_VARIETY'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İzmir'de vejetaryen menüsü geniş restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'izmir'
                AND rating.dimension = 'FOOD_VARIETY'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İzmir'de sushi menüsü olan mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'izmir'
                AND rating.dimension = 'FOOD_VARIETY'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İstanbul'da vegan kahvaltıcılar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'istanbul'
                AND rating.dimension = 'FOOD_VARIETY'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İstanbul'da İtalyan mutfağı restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'istanbul'
                AND rating.dimension = 'FOOD_VARIETY'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İstanbul'da hamburger yapan dükkânlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'istanbul'
                AND rating.dimension = 'FOOD_VARIETY'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İstanbul'da Lübnan mutfağı restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'istanbul'
                AND rating.dimension = 'FOOD_VARIETY'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Ankara'da etli ekmek yapan lokantalar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE toLower(l.name) CONTAINS 'ankara'
                AND rating.dimension = 'FOOD_VARIETY'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Tüm şehirlerde şarap menüsü geniş restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[rating:RATED_FOR]->(a:Aspect)
                WHERE rating.dimension = 'BEVERAGE_VARIETY'
                AND rating.sentiment = 'positive'
                RETURN r.name as restoran, l.name as sehir
                LIMIT 10
            """
        },
        {
            "name": "En yüksek tat puanı alan restoranlar",
            "query": """
                MATCH (r:Restaurant)-[rating:RATED_FOR]->(a:Aspect)
                WHERE rating.dimension = 'TASTE' AND rating.sentiment = 'positive'
                RETURN r.name as restoran, rating.score as puan
                ORDER BY rating.score DESC
                LIMIT 10
            """
        },
        {
            "name": "En yüksek servis puanı alan restoranlar",
            "query": """
                MATCH (r:Restaurant)-[rating:RATED_FOR]->(a:Aspect)
                WHERE rating.dimension = 'SERVICE' AND rating.sentiment = 'positive'
                RETURN r.name as restoran, rating.score as puan
                ORDER BY rating.score DESC
                LIMIT 10
            """
        },
        {
            "name": "En temiz restoranlar",
            "query": """
                MATCH (r:Restaurant)-[rating:RATED_FOR]->(a:Aspect)
                WHERE rating.dimension = 'CLEANLINESS' AND rating.sentiment = 'positive'
                RETURN r.name as restoran, rating.score as puan
                ORDER BY rating.score DESC
                LIMIT 10
            """
        },
        {
            "name": "En iyi ambiyans puanı alan mekanlar",
            "query": """
                MATCH (r:Restaurant)-[rating:RATED_FOR]->(a:Aspect)
                WHERE rating.dimension = 'AMBIANCE' AND rating.sentiment = 'positive'
                RETURN r.name as restoran, rating.score as puan
                ORDER BY rating.score DESC
                LIMIT 10
            """
        },
        {
            "name": "En çok menü çeşitliliği olan restoranlar",
            "query": """
                MATCH (r:Restaurant)-[rating:RATED_FOR]->(a:Aspect)
                WHERE rating.dimension = 'FOOD_VARIETY' AND rating.sentiment = 'positive'
                RETURN r.name as restoran, rating.score as puan
                ORDER BY rating.score DESC
                LIMIT 10
            """
        },
        {
            "name": "Düşük tat puanı alan restoranlar",
            "query": """
                MATCH (r:Restaurant)-[rating:RATED_FOR]->(a:Aspect)
                WHERE rating.dimension = 'TASTE' AND rating.sentiment = 'negative'
                RETURN r.name as restoran, rating.score as puan
                ORDER BY rating.score ASC
                LIMIT 10
            """
        },
        {
            "name": "Kötü servis puanı alan restoranlar",
            "query": """
                MATCH (r:Restaurant)-[rating:RATED_FOR]->(a:Aspect)
                WHERE rating.dimension = 'SERVICE' AND rating.sentiment = 'negative'
                RETURN r.name as restoran, rating.score as puan
                ORDER BY rating.score ASC
                LIMIT 10
            """
        },
        {
            "name": "Hijyen problemi olan restoranlar",
            "query": """
                MATCH (r:Restaurant)-[rating:RATED_FOR]->(a:Aspect)
                WHERE rating.dimension = 'CLEANLINESS' AND rating.sentiment = 'negative'
                RETURN r.name as restoran, rating.score as puan
                ORDER BY rating.score ASC
                LIMIT 10
            """
        },
        {
            "name": "Gürültülü ambiyans şikayeti olan mekanlar",
            "query": """
                MATCH (r:Restaurant)-[rating:RATED_FOR]->(a:Aspect)
                WHERE rating.dimension = 'AMBIANCE' AND rating.sentiment = 'negative'
                RETURN r.name as restoran, rating.score as puan
                ORDER BY rating.score ASC
                LIMIT 10
            """
        },
        {
            "name": "Fiyat şikayeti olan restoranlar",
            "query": """
                MATCH (r:Restaurant)-[rating:RATED_FOR]->(a:Aspect)
                WHERE rating.dimension = 'VALUE' AND rating.sentiment = 'negative'
                RETURN r.name as restoran, rating.score as puan
                ORDER BY rating.score ASC
                LIMIT 10
            """
        },

        # 41-60: Occasion-based queries
        {
            "name": "Romantik akşam yemeği için uygun mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(o.name) CONTAINS 'romantik'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İş yemeği için uygun restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(o.name) CONTAINS 'iş'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Doğum günü kutlaması için uygun mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(o.name) CONTAINS 'doğum günü'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Nişan yemeği için uygun restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(o.name) CONTAINS 'nişan'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Mezuniyet yemeği için uygun mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(o.name) CONTAINS 'mezuniyet'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Yılbaşı kutlaması için uygun restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(o.name) CONTAINS 'yılbaşı'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Arkadaş buluşması için uygun mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(o.name) CONTAINS 'arkadaş'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Aile yemeği için uygun restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(o.name) CONTAINS 'aile'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Ankara'da romantik mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(l.name) CONTAINS 'ankara'
                AND toLower(o.name) CONTAINS 'romantik'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İzmir'de romantik mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(l.name) CONTAINS 'izmir'
                AND toLower(o.name) CONTAINS 'romantik'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İstanbul'da romantik mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(l.name) CONTAINS 'istanbul'
                AND toLower(o.name) CONTAINS 'romantik'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Ankara'da iş yemeği için uygun mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(l.name) CONTAINS 'ankara'
                AND toLower(o.name) CONTAINS 'iş'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İzmir'de iş yemeği için uygun mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(l.name) CONTAINS 'izmir'
                AND toLower(o.name) CONTAINS 'iş'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İstanbul'da iş yemeği için uygun mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(l.name) CONTAINS 'istanbul'
                AND toLower(o.name) CONTAINS 'iş'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Ankara'da doğum günü kutlaması için mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(l.name) CONTAINS 'ankara'
                AND toLower(o.name) CONTAINS 'doğum günü'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İzmir'de doğum günü kutlaması için mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(l.name) CONTAINS 'izmir'
                AND toLower(o.name) CONTAINS 'doğum günü'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "İstanbul'da doğum günü kutlaması için mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:LOCATED_IN]->(l:Location)
                MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(l.name) CONTAINS 'istanbul'
                AND toLower(o.name) CONTAINS 'doğum günü'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Loş ışıklı romantik restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:HAS_AMENITY]->(am:Amenity)
                MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(am.name) CONTAINS 'loş ışık'
                AND toLower(o.name) CONTAINS 'romantik'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Süsleme yapan doğum günü mekanları",
            "query": """
                MATCH (r:Restaurant)-[:HAS_AMENITY]->(am:Amenity)
                MATCH (r)-[:SUITS_OCCASION]->(o:Occasion)
                WHERE toLower(am.name) CONTAINS 'süsleme'
                AND toLower(o.name) CONTAINS 'doğum günü'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Pasta servisi olan kafeler",
            "query": """
                MATCH (r:Restaurant)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(am.name) CONTAINS 'pasta'
                RETURN r.name as restoran
                LIMIT 10
            """
        },

        # 61-80: Amenity-focused queries
        {
            "name": "Restoranların imkanları",
            "query": """
                MATCH (r:Restaurant)-[:HAS_AMENITY]->(am:Amenity)
                RETURN r.name as restoran, collect(am.name) as imkanlar
                LIMIT 10
            """
        },
        {
            "name": "En çok amenity'ye sahip restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:HAS_AMENITY]->(am:Amenity)
                RETURN r.name as restoran, count(am) as amenity_sayisi
                ORDER BY amenity_sayisi DESC
                LIMIT 10
            """
        },
        {
            "name": "WiFi olan kafeler",
            "query": """
                MATCH (r:Restaurant)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(am.name) CONTAINS 'wifi'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Klimalı restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(am.name) CONTAINS 'klima'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Vale park hizmeti olan mekanlar",
            "query": """
                MATCH (r:Restaurant)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(am.name) CONTAINS 'vale'
                RETURN r.name as restoran
                LIMIT 10
            """
        },
        {
            "name": "Kart ile ödeme kabul eden restoranlar",
            "query": """
                MATCH (r:Restaurant)-[:HAS_AMENITY]->(am:Amenity)
                WHERE toLower(am.name) CONTAINS 'kart'
                RETURN r.name as restoran
                LIMIT 10
            """
        },

    ]

    # DataFrame oluşturuluyor
    all_results = []  # Sonuçları depolayacağımız liste

    with kg.driver.session() as session:
        for q in queries:
            input_query = q["name"]
            output_results = []  # Çıktıları depolayacağımız liste

            print(f"Sorgu: {input_query}")

            try:
                result = session.run(q['query'])
                records = list(result)

                if records:
                    print(f"   ✓ {len(records)} sonuç bulundu:")
                    for record in records:
                        output_results.append(record["restoran"])  # Restoran adlarını ekle
                else:
                    print("   ⚠ Sonuç bulunamadı")

            except Exception as e:
                print(f"   ❌ Sorgu hatası: {e}")

            # Input ve Output'u DataFrame'e ekliyoruz
            for result in output_results:
                all_results.append([input_query, result])

    # DataFrame oluşturuluyor
    df = pd.DataFrame(all_results, columns=["Input", "Output"])

    return df

# %%
# Neo4j bağlantısını başlatıyoruz
kg = Neo4jKnowledgeGraph(uri="bolt://localhost:7687", user="neo4j", password="12345678")
df_results = run_queries_and_store_results(kg)

# Sonuçları yazdır
print(df_results)
# Out:
# Sorgu: Ankara'daki mekanlar
#    ✓ 10 sonuç bulundu:
# Sorgu: Olumlu tat puanı alan restoranlar
#    ✓ 10 sonuç bulundu:
# Sorgu: Restoranların imkanları
#    ✓ 10 sonuç bulundu:
# Sorgu: İstanbul'da romantik ve yüksek tat puanı olan restoranlar
#    ✓ 10 sonuç bulundu:
#                                                 Input  \
# 0                                Ankara'daki mekanlar
# 1                                Ankara'daki mekanlar
# 2                                Ankara'daki mekanlar
# 3                                Ankara'daki mekanlar
# 4                                Ankara'daki mekanlar
# 5                                Ankara'daki mekanlar
# 6                                Ankara'daki mekanlar
# 7                                Ankara'daki mekanlar
# 8                                Ankara'daki mekanlar
# 9                                Ankara'daki mekanlar
# 10                  Olumlu tat puanı alan restoranlar
# 11                  Olumlu tat puanı alan restoranlar
# 12                  Olumlu tat puanı alan restoranlar
# 13                  Olumlu tat puanı alan restoranlar
# 14                  Olumlu tat puanı alan restoranlar
# 15                  Olumlu tat puanı alan restoranlar
# 16                  Olumlu tat puanı alan restoranlar
# 17                  Olumlu tat puanı alan restoranlar
# 18                  Olumlu tat puanı alan restoranlar
# 19                  Olumlu tat puanı alan restoranlar
# 20                            Restoranların imkanları
# 21                            Restoranların imkanları
# 22                            Restoranların imkanları
# 23                            Restoranların imkanları
# 24                            Restoranların imkanları
# 25                            Restoranların imkanları
# 26                            Restoranların imkanları
# 27                            Restoranların imkanları
# 28                            Restoranların imkanları
# 29                            Restoranların imkanları
# 30  İstanbul'da romantik ve yüksek tat puanı olan ...
# 31  İstanbul'da romantik ve yüksek tat puanı olan ...
# 32  İstanbul'da romantik ve yüksek tat puanı olan ...
# 33  İstanbul'da romantik ve yüksek tat puanı olan ...
# 34  İstanbul'da romantik ve yüksek tat puanı olan ...
# 35  İstanbul'da romantik ve yüksek tat puanı olan ...
# 36  İstanbul'da romantik ve yüksek tat puanı olan ...
# 37  İstanbul'da romantik ve yüksek tat puanı olan ...
# 38  İstanbul'da romantik ve yüksek tat puanı olan ...
# 39  İstanbul'da romantik ve yüksek tat puanı olan ...
#
#                                     Output
# 0                     beyzade_cafe_elmadag
# 1                          bolu_mangal_evi
# 2                               cafemodern
# 3               annem_pide_ve_kebap_salonu
# 4                       akin_usta_iskender
# 5             can_dadas_erzurum_cag_kebabi
# 6                      akdeniz_iskembecisi
# 7                               bey_aspava
# 8                   babanin_yeri_lokantasi
# 9               altinova_pide_kebap_salonu
# 10         hakki_ustanin_yeri_yemek_sanayi
# 11                                 biyesen
# 12          are_pizza_simit_cafe_fast_food
# 13            baglum_halil_ibrahim_sofrasi
# 14                     bolu_akin_lokantasi
# 15  ankaraguclu_bora_kokorec_ve_sirdan_evi
# 16          avsaroglu_pide_ve_kebap_salonu
# 17            can_dadas_erzurum_cag_kebabi
# 18            can_dadas_erzurum_cag_kebabi
# 19                       akpinar_lokantasi
# 20                 bahceli_cafe_restaurant
# 21          big_chefs_kiyi_istanbul_subesi
# 22                  adaturka_kafe_restoran
# 23                  deniz_kalbi_restaurant
# 24                  swan_cafe_restoran_bar
# 25                              akira_back
# 26                           fuaye_kalamis
# 27                casa_de_costa_restaurant
# 28                         cordon_cafe_bar
# 29              heinz_beck_restaurant_cafe
# 30              bahceli_etbalik_restaurant
# 31                the_hunger_kiyi_istanbul
# 32                            biz_istanbul
# 33                     trattoria_carbonara
# 34                                  aralik
# 35                      hemdem_steak_house
# 36                  sky_rooftop_restaurant
# 37                               bonissimo
# 38  le_vapeur_magique_tdi_karakoy_iskelesi
# 39               roof_mezze_360_restaurant

# %%
df_results
# Out:
#                                                 Input  \
# 0                                Ankara'daki mekanlar
# 1                                Ankara'daki mekanlar
# 2                                Ankara'daki mekanlar
# 3                                Ankara'daki mekanlar
# 4                                Ankara'daki mekanlar
# 5                                Ankara'daki mekanlar
# 6                                Ankara'daki mekanlar
# 7                                Ankara'daki mekanlar
# 8                                Ankara'daki mekanlar
# 9                                Ankara'daki mekanlar
# 10                  Olumlu tat puanı alan restoranlar
# 11                  Olumlu tat puanı alan restoranlar
# 12                  Olumlu tat puanı alan restoranlar
# 13                  Olumlu tat puanı alan restoranlar
# 14                  Olumlu tat puanı alan restoranlar
# 15                  Olumlu tat puanı alan restoranlar
# 16                  Olumlu tat puanı alan restoranlar
# 17                  Olumlu tat puanı alan restoranlar
# 18                  Olumlu tat puanı alan restoranlar
# 19                  Olumlu tat puanı alan restoranlar
# 20                            Restoranların imkanları
# 21                            Restoranların imkanları
# 22                            Restoranların imkanları
# 23                            Restoranların imkanları
# 24                            Restoranların imkanları
# 25                            Restoranların imkanları
# 26                            Restoranların imkanları
# 27                            Restoranların imkanları
# 28                            Restoranların imkanları
# 29                            Restoranların imkanları
# 30  İstanbul'da romantik ve yüksek tat puanı olan ...
# 31  İstanbul'da romantik ve yüksek tat puanı olan ...
# 32  İstanbul'da romantik ve yüksek tat puanı olan ...
# 33  İstanbul'da romantik ve yüksek tat puanı olan ...
# 34  İstanbul'da romantik ve yüksek tat puanı olan ...
# 35  İstanbul'da romantik ve yüksek tat puanı olan ...
# 36  İstanbul'da romantik ve yüksek tat puanı olan ...
# 37  İstanbul'da romantik ve yüksek tat puanı olan ...
# 38  İstanbul'da romantik ve yüksek tat puanı olan ...
# 39  İstanbul'da romantik ve yüksek tat puanı olan ...
#
#                                     Output
# 0                     beyzade_cafe_elmadag
# 1                          bolu_mangal_evi
# 2                               cafemodern
# 3               annem_pide_ve_kebap_salonu
# 4                       akin_usta_iskender
# 5             can_dadas_erzurum_cag_kebabi
# 6                      akdeniz_iskembecisi
# 7                               bey_aspava
# 8                   babanin_yeri_lokantasi
# 9               altinova_pide_kebap_salonu
# 10         hakki_ustanin_yeri_yemek_sanayi
# 11                                 biyesen
# 12          are_pizza_simit_cafe_fast_food
# 13            baglum_halil_ibrahim_sofrasi
# 14                     bolu_akin_lokantasi
# 15  ankaraguclu_bora_kokorec_ve_sirdan_evi
# 16          avsaroglu_pide_ve_kebap_salonu
# 17            can_dadas_erzurum_cag_kebabi
# 18            can_dadas_erzurum_cag_kebabi
# 19                       akpinar_lokantasi
# 20                 bahceli_cafe_restaurant
# 21          big_chefs_kiyi_istanbul_subesi
# 22                  adaturka_kafe_restoran
# 23                  deniz_kalbi_restaurant
# 24                  swan_cafe_restoran_bar
# 25                              akira_back
# 26                           fuaye_kalamis
# 27                casa_de_costa_restaurant
# 28                         cordon_cafe_bar
# 29              heinz_beck_restaurant_cafe
# 30              bahceli_etbalik_restaurant
# 31                the_hunger_kiyi_istanbul
# 32                            biz_istanbul
# 33                     trattoria_carbonara
# 34                                  aralik
# 35                      hemdem_steak_house
# 36                  sky_rooftop_restaurant
# 37                               bonissimo
# 38  le_vapeur_magique_tdi_karakoy_iskelesi
# 39               roof_mezze_360_restaurant
